# %%
pwd
# Out:
# /mnt/HDD500/0WORKSHOP-with-NOTEBOOKS

# %%
ls Temp
# Out:
# image01.jpg  image02.jpg  video6.mp4

# %%
identify -format "%wx%h" Temp/image01.jpg
# Out:
# 512x1024

# %%
identify -format "%wx%h" Temp/output.jpg
# Out:
# 512x400

# %% [raw]
# ffmpeg -hide_banner -loop 1 -i Temp/image01.jpg  -vf "[0]zoompan=z='min(zoom+0.0015,1.5)':d=150:x='if(gte(zoom,1.5),x,x+1.5)':y='if(gte(zoom,1.5),y,y+2)':s=512x768" -pix_fmt yuv420p -c:v libx264 -t 15 Temp/output_video.mp4

# %%
Explanation of the command and its options:

-loop 1 loops the input image indefinitely.
-i input_image.jpg specifies the input image file.
-filter_complex allows us to apply complex filtergraphs.
[0]zoompan=z='min(zoom+0.0015,1.5)':d=150:x='if(gte(zoom,1.5),x,x+1.5)':y='if(gte(zoom,1.5),y,y+2)':s=512x768 is the filtergraph that applies the pan and zoom effect. 
Here's what each parameter does:
z='min(zoom+0.0015,1.5)' specifies the zoom level. The min function limits the maximum zoom to 1.5x.
d=150 specifies the duration of each frame in milliseconds. A smaller value makes the zoom and pan smoother.
x='if(gte(zoom,1.5),x,x+1.5)' and y='if(gte(zoom,1.5),y,y+2)' specify the coordinates of the zooming region. The if function makes sure that the zooming region stays fixed once it reaches the desired size.
s=512x768 specifies the output size of the video.
-pix_fmt yuv420p specifies the pixel format of the output video.
-c:v libx264 specifies the video codec to use.
-t 15 specifies the duration of the output video.
This command should create a 15-second video with a smooth pan and zoom effect on the head region of the input image, with an output size of 512x768.

# %%
ffmpeg -hide_banner -loop 1 -i Temp/image01.jpg  -vf "[0]zoompan=z='min(zoom+0.0015,1.5)':d=250:x='if(gte(zoom,1.5),x,x+1.5)':y='if(gte(zoom,1.5),y,y+2)':s=512x768" -pix_fmt yuv420p -c:v libx264 -t 15 Temp/output_videod-250.mp4
# Out:
# Input #0, image2, from 'Temp/image01.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 119318 kb/s
#     Stream #0:0: Video: mjpeg (Progressive), yuvj444p(pc, bt470bg/unknown/unknown), 512x1024 [SAR 300:300 DAR 1:2], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x558dcf393bc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x558dcf4deb40] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x558dcf4deb40] Warning: data is not aligned! This can lead to a speed loss
# [libx264 @ 0x558dcf113e00] using SAR=1/1
# [libx264 @ 0x558dcf113e00] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x558dcf113e00] profile High, level 3.0
# ...

# %%
ffmpeg -hide_banner -loop 1 -i Temp/image01.jpg  -vf "[0]zoompan=z='min(zoom+0.0015,1.5)':d=100:x='if(gte(zoom,1.5),x,x+1.5)':y='if(gte(zoom,1.5),y,y+2)':s=512x768" -pix_fmt yuv420p -c:v libx264 -t 30 Temp/output_video_d-100-30.mp4
# Out:
# Input #0, image2, from 'Temp/image01.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 119318 kb/s
#     Stream #0:0: Video: mjpeg (Progressive), yuvj444p(pc, bt470bg/unknown/unknown), 512x1024 [SAR 300:300 DAR 1:2], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55645da6fbc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55645dbbab40] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55645dbbab40] Warning: data is not aligned! This can lead to a speed loss
# [libx264 @ 0x55645d7efe00] using SAR=1/1
# [libx264 @ 0x55645d7efe00] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x55645d7efe00] profile High, level 3.0
# ...

# %%
ffmpeg -hide_banner -loop 1 -i Temp/image01.jpg -filter_complex \
"[0]scale=512:1024,setsar=1:1,crop=w=512:h=768:x=0:y=256,zoompan=z='zoom+2':d=150:s=512x768" \
-codec:a copy -t 30 -y Temp/ZOOM5.mp4
# Out:
# Input #0, image2, from 'Temp/image01.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 119318 kb/s
#     Stream #0:0: Video: mjpeg (Progressive), yuvj444p(pc, bt470bg/unknown/unknown), 512x1024 [SAR 300:300 DAR 1:2], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (mjpeg) -> scale
#   zoompan -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [swscaler @ 0x558529761fc0] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x5585293bf940] using SAR=1/1
# [libx264 @ 0x5585293bf940] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x5585293bf940] profile High 4:4:4 Predictive, level 3.0, 4:4:4 8-bit
# ...

# %%
ffmpeg -hide_banner -loop 1 -i Temp/image01.jpg -filter_complex \
"[0]scale=512:1024, zoompan=z='min(zoom+0.002,5)':d=30:x='if(gte(zoom,1.5),x,x+1/a)':y='if(gte(zoom,1.5),y,y+1)':s=512x768[out]" \
-map "[out]" -pix_fmt yuv420p -r 25 -t 30 Temp/outputslower.mp4
# Out:
# Input #0, image2, from 'Temp/image01.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 119318 kb/s
#     Stream #0:0: Video: mjpeg (Progressive), yuvj444p(pc, bt470bg/unknown/unknown), 512x1024 [SAR 300:300 DAR 1:2], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (mjpeg) -> scale
#   zoompan -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [swscaler @ 0x5579e1367400] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x5579e14e3000] Warning: data is not aligned! This can lead to a speed loss
# [libx264 @ 0x5579e10ea800] using SAR=1/1
# [libx264 @ 0x5579e10ea800] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x5579e10ea800] profile High, level 3.0
# ...

# %%
/home/jack/Desktop/animate/20230506_215842644archived-images1.mp4

# %%
ffmpeg -hide_banner -loop 1 -i Temp/image01.jpg  -vf "zoompan=z='min(max(zoom,pzoom)+0.0015,1.5)':d=25:x='if(gte(zoom,1.5),x,x+1)':y='if(gte(zoom,1.5),y,y+1)':s=512x1024, crop=512:400:0:0, scale=512:768" -pix_fmt yuv420p -c:v libx264 -t 10 -y Temp/outputxx.mp4
# Out:
# Input #0, image2, from 'Temp/image01.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 119318 kb/s
#     Stream #0:0: Video: mjpeg (Progressive), yuvj444p(pc, bt470bg/unknown/unknown), 512x1024 [SAR 300:300 DAR 1:2], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55e696b60500] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55e696d07d80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55e696d07d80] Warning: data is not aligned! This can lead to a speed loss
# [libx264 @ 0x55e6968dbe40] using SAR=48/25
# [libx264 @ 0x55e6968dbe40] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x55e6968dbe40] profile High, level 3.0
# ...

# %%
ffmpeg -hide_banner -i Temp/image01.jpg -vf "zoompan=z='min(max(zoom,pzoom)+0.0015,1.5)':d=25:x='if(gte(zoom,1.5),x,x+1)':y='if(gte(zoom,1.5),y,y+1)':s=512x1024, crop=512:1024:0:0" -y Temp/output.jpg
# Out:
# Input #0, image2, from 'Temp/image01.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 119318 kb/s
#     Stream #0:0: Video: mjpeg (Progressive), yuvj444p(pc, bt470bg/unknown/unknown), 512x1024 [SAR 300:300 DAR 1:2], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5573016bb140] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x5573016bb140] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'Temp/output.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 512x1024 [SAR 300:300 DAR 1:2], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# ...

# %%
ffmpeg -hide_banner -loop 1 -i Temp/image01.jpg -filter_complex "zoompan=z='if(lte(zoom,1.5),1.5,max(1.001,zoom-.0015))':d=25:x='if(lte(zoom,1.5),x,x+1)':y='if(lte(zoom,1.5),y,y+1)', crop=512:400:0:0, scale=512:768, setsar=1:2, pan=st(0,1)*iw/2:st(0,1)*ih/2" -pix_fmt yuv420p -c:v libx264 -t 10 -y Temp/output2.mp4
# Out:
# Input #0, image2, from 'Temp/image01.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 119318 kb/s
#     Stream #0:0: Video: mjpeg (Progressive), yuvj444p(pc, bt470bg/unknown/unknown), 512x1024 [SAR 300:300 DAR 1:2], 25 fps, 25 tbr, 25 tbn, 25 tbc
# [Parsed_pan_4 @ 0x55d61df32280] Invalid channel layout 'st(0'
# [AVFilterGraph @ 0x55d61df2b100] Error initializing filter 'pan' with args 'st(0'
# Error initializing complex filters.
# Invalid argument
# : 1

# %%
ffmpeg -hide_banner -loop 1 -i Temp/image01.jpg  -vf "zoompan=z='min(max(zoom,pzoom)+0.0015,1.5)':d=25:x='if(gte(zoom,1.5),x,x+1)':y='if(gte(zoom,1.5),y,y+1)':s=512x1024, crop=512:400:0:0, scale=512:768, setsar=1:2" -pix_fmt yuv420p -c:v libx264 -t 10 -y Temp/output2.mp4
# Out:
# Input #0, image2, from 'Temp/image01.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 119318 kb/s
#     Stream #0:0: Video: mjpeg (Progressive), yuvj444p(pc, bt470bg/unknown/unknown), 512x1024 [SAR 300:300 DAR 1:2], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5640c9a32fc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x5640c9bdb140] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x5640c9bdb140] Warning: data is not aligned! This can lead to a speed loss
# [libx264 @ 0x5640c97ace40] using SAR=1/1
# [libx264 @ 0x5640c97ace40] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x5640c97ace40] profile High, level 3.0
# ...

# %%
ffmpeg -hide_banner -loop 1 -i Temp/image01.jpg  -vf "zoompan=z='min(max(zoom,pzoom)+0.0015,1.5)':d=25:x='if(gte(zoom,1.5),x,x+1)':y='if(gte(zoom,1.5),y,y+1)':s=512x1024, crop=512:400:0:0, scale=512:768, transpose=1" -pix_fmt yuv420p -c:v libx264 -t 10 -y Temp/output2.mp4
# Out:
# Input #0, image2, from 'Temp/image01.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 119318 kb/s
#     Stream #0:0: Video: mjpeg (Progressive), yuvj444p(pc, bt470bg/unknown/unknown), 512x1024 [SAR 300:300 DAR 1:2], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x559279f2e300] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55927a0d6480] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55927a0d6480] Warning: data is not aligned! This can lead to a speed loss
# [libx264 @ 0x559279ca7e40] using SAR=25/48
# [libx264 @ 0x559279ca7e40] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x559279ca7e40] profile High, level 3.0
# ...

# %%
ffmpeg -i input.jpg -vf "zoompan=z='min(max(zoom,pzoom)+0.0015,1.5)':d=25:x='if(gte(zoom,1.5),x,x+1)':y='if(gte(zoom,1.5),y,y+1)':s=512x1024, crop=512:400:0:0" output.jpg

# %%
ffmpeg -hide_banner -i Temp/image01.jpg  -vf "transpose=1,transpose=1,transpose=1,auto-orient" Temp/output.jpg
# Out:
# Input #0, image2, from 'Temp/image01.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 119318 kb/s
#     Stream #0:0: Video: mjpeg (Progressive), yuvj444p(pc, bt470bg/unknown/unknown), 512x1024 [SAR 300:300 DAR 1:2], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [AVFilterGraph @ 0x55fe02e2ee80] No such filter: 'auto-orient'
# Error reinitializing filters!
# Failed to inject frame into filter network: Invalid argument
# Error while processing the decoded data for stream #0:0
# Conversion failed!
# : 1

# %%
ffmpeg -hide_banner -i Temp/image01.jpg -filter_complex \
"[0]crop=iw:400:0:0,scale=1920:-1,zoompan=z='min(max(zoom,pzoom)+0.01,1.5)':d=125,trim=duration=10[out]" \
-acodec aac -vcodec libx264 -map [out] -pix_fmt yuv420p -r 25 -t 10 -y Temp/video01.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
image01="/home/jack/Desktop/HDD500/collections/disney_banksy/zoom/DreamShaper_32_disney_banksy_art_sticker_fantasy_character_sou_0.jpg"
image02="/home/jack/Desktop/HDD500/collections/disney_banksy/zoom/DreamShaper_32_disney_banksy_art_sticker_fantasy_character_sou_1.jpg"
image03="/home/jack/Desktop/HDD500/collections/disney_banksy/zoom/DreamShaper_32_disney_banksy_art_sticker_fantasy_character_sou_2.jpg"

# %%
echo ${image01}
# Out:
# /home/jack/Desktop/HDD500/collections/disney_banksy/zoom/DreamShaper_32_disney_banksy_art_sticker_fantasy_character_sou_0.jpg

# %%
ffmpeg -hide_banner -loop 1 -i CivatAI/00021-3863176697.jpeg -y -filter_complex \
"[0]scale=1200:-2,setsar=1:1[out]; \
[out]crop=640:670[out]; \
[out]scale=8000:-1,zoompan=z='zoom+0.001':x=0:y=0:d=250:s=670x1200:fps=25[out]" \
-acodec aac -vcodec libx264 -map [out] -map 0:a? -pix_fmt yuv420p -r 25 -t 10 Temp/video6.mp4
# Out:
# Input #0, image2, from 'CivatAI/00021-3863176697.jpeg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 8754 kb/s
#     Stream #0:0: Video: mjpeg (Progressive), yuvj420p(pc, bt470bg/unknown/unknown), 450x675 [SAR 1:1 DAR 2:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (mjpeg) -> scale
#   zoompan -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [swscaler @ 0x5578bac3ca80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x5578bac499c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x5578bac499c0] Warning: data is not aligned! This can lead to a speed loss
# [libx264 @ 0x5578ba40c140] using SAR=1/1
# [libx264 @ 0x5578ba40c140] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x5578ba40c140] profile High, level 3.1
# ...

# %%
ffmpeg -hide_banner -loop 1 -i CivatAI/00021-3863176697.jpeg -y -filter_complex \
[0]scale=1200:-2,setsar=1:1[out];[out]crop=1200:670[out]; \
[out]scale=8000:-1,zoompan=z='zoom+0.001':x=0:y=0:d=250:s=1200x670:fps=25[out] \
-acodec aac -vcodec libx264 -map [out] -map 0:a? -pix_fmt yuv420p -r 25 -t 10 Temp/video6.mp4
# Out:
# Input #0, image2, from 'CivatAI/00021-3863176697.jpeg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 8754 kb/s
#     Stream #0:0: Video: mjpeg (Progressive), yuvj420p(pc, bt470bg/unknown/unknown), 450x675 [SAR 1:1 DAR 2:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Filter setsar has an unconnected output
# [out]crop=1200:670[out]: command not found
# [out]scale=8000:-1,zoompan=z=zoom+0.001:x=0:y=0:d=250:s=1200x670:fps=25[out]: command not found
# : 127

# %%
ffmpeg -loop 1 -i ${image01} -y -filter_complex \
[0]scale=1200:-2,setsar=1:1[out];[out]crop=1200:670[out];\
[out]scale=8000:-1,zoompan=z='zoom+0.001':x=0:y=0:d=250:s=1200x670:fps=25[out] \
-acodec aac -vcodec libx264 -map [out] -map 0:a? -pix_fmt yuv420p -r 25 -t 10 Temp/video6.mp4

ffmpeg -loop 1 -i ${image02} -y -filter_complex \
"[0]scale=1200:-2,setsar=1[out];[out]crop=1200:670[out]; \
 [out]scale=8000:-1,zoompan=z='zoom+0.001':x=0:y=0:d=250:s=1200x670:fps=25[out]" \
-acodec aac -vcodec libx264 -map "[out]" -map 0:a? -pix_fmt yuv420p -r 25 -t 10 Temp/video07a.mp4

ffmpeg -loop 1 -i ${image03} -y -filter_complex \
"[0]scale=1200:-2,setsar=1:1[out];[out]crop=1200:670[out]; \
[out]scale=8000:-1,zoompan=z='zoom+0.001':x=iw/2-(iw/zoom/2):y=0:d=250:s=1200x670:fps=25[out]" \
-acodec aac -vcodec libx264 -map [out] -map 0:a? -pix_fmt yuv420p -r 25 -t 10 Temp/video07.mp4


ffmpeg -loop 1 -i 0008.jpg -y -filter_complex \
"[0]scale=1200:-2,setsar=1:1[out];[out]crop=1200:670[out]; \
[out]scale=8000:-1,zoompan=z='zoom+0.001':x=iw/2-(iw/zoom/2):y=ih/2-(ih/zoom/2):d=250:s=1200x670:fps=25[out]" \
-acodec aac -vcodec libx264 -map [out] -map 0:a? -pix_fmt yuv420p -r 25 -t 10 Temp/video08.mp4

# %%
/home/jack/Desktop/HDD500/Downloads/saved_pages/WORKSHOP-with-NOTEBOOKS/EXPERIMENT/output_video.mp4
# Out:
# frame=11234 fps=5.1 q=-1.0 Lsize=   11373kB time=00:07:29.24 bitrate= 207.4kbits/s speed=0.205x
# video:11241kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.177465%
# [libx264 @ 0x562ceba34fc0] frame I:46    Avg QP:17.50  size:113109
# [libx264 @ 0x562ceba34fc0] frame P:2841  Avg QP:17.65  size:  1357
# [libx264 @ 0x562ceba34fc0] frame B:8347  Avg QP:24.13  size:   294
# [libx264 @ 0x562ceba34fc0] consecutive B-frames:  0.9%  0.1%  0.3% 98.7%
# [libx264 @ 0x562ceba34fc0] mb I  I16..4:  2.1% 49.8% 48.0%
# [libx264 @ 0x562ceba34fc0] mb P  I16..4:  0.1%  1.1%  0.4%  P16..4:  1.9%  0.9%  0.4%  0.0%  0.0%    skip:95.2%
# [libx264 @ 0x562ceba34fc0] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8:  1.2%  0.5%  0.2%  direct: 0.3%  skip:97.7%  L0:32.8% L1:39.1% BI:28.1%
# [libx264 @ 0x562ceba34fc0] 8x8 transform intra:61.5% inter:66.0%
# [libx264 @ 0x562ceba34fc0] coded y,uvDC,uvAC intra: 93.6% 87.1% 59.5% inter: 1.2% 1.2% 0.1%
# ...

# %%
# GOOD VIDEO
ffmpeg -hide_banner -i /home/jack/Desktop/HDD500/MyTube_AI_Flask_App/EXPERIMENT/output.mp4 -filter:v "scale=512:666,setpts=40*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=400'" -t 58 -y EXPERIMENT/output_lexica-warrior1.mp4
# Out:
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/jack/Desktop/HDD500/MyTube_AI_Flask_App/EXPERIMENT/output.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:29.90, start: 0.000000, bitrate: 967 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x768, 964 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f5a6f31000] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x55f5a6f31000] profile High, level 3.0
# ...

# %%
# GOOD VIDEO
ffmpeg -hide_banner -i /home/jack/Desktop/HDD500/MyTube_AI_Flask_App/EXPERIMENT/output.mp4 -filter:v "setpts=40*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=400'" -t 58 -y EXPERIMENT/output_lexica-warrior1.mp4
# Out:
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/jack/Desktop/HDD500/MyTube_AI_Flask_App/EXPERIMENT/output.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:29.90, start: 0.000000, bitrate: 967 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x768, 964 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f5a6f31000] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x55f5a6f31000] profile High, level 3.0
# ...

# %%
# GOOD VIDEO
ffmpeg -hide_banner -i EXPERIMENT/output.mp4 -filter:v "setpts=20*PTS,minterpolate='fps=25:scd=fast:me_mode=bidir:vsbmc=1:search_param=400'" -y EXPERIMENT/output_lexica-warrior-sdc-fast1.mp4

# %%
ffmpeg -i EXPERIMENT/lexica-warrior_video4.mp4 -filter:v "setpts=0.5*PTS" EXPERIMENT/setpts_0-5_PTS_lexica-warrior.mkv

# %%
output_video='EXPERIMENT/lexica-warrior_video4.mp4'
ffmpeg -i ${output_video} -filter:v "setpts=40*PTS,minterpolate='fps=25:me_mode=bidir:vsbmc=1:search_param=400'" -y EXPERIMENT/lnm_faces_sp400_lexica-warrior.mp4

# %%
output_video='EXPERIMENT/lexica-warrior_video4.mp4'
ffmpeg -i ${output_video} -filter:v "setpts=20*PTS,minterpolate='fps=25:me_mode=bidir:vsbmc=1:search_param=200'" -y EXPERIMENT/lexica-warrior_sp20_para200.mp4

# %%
!locate lexica-warrior_video4.mp4

# %%
timestamp=$(date +%Y-%m-%d_%H-%M-%S)

# %%
#!/bin/bash

# Get the current date and time in the format YYYY-MM-DD_HH-MM-SS
timestamp=$(date +%Y-%m-%d_%H-%M-%S)

# Create the filename with the timestamp
filename="video_${timestamp}.mp4"


# Print the filename for confirmation
echo ${filename}

# %%
timestamp=$(date +%Y-%m-%d_%H-%M-%S)
output_video='EXPERIMENT/lexica-warrior_${timestamp}.mp4'
ffmpeg -i /home/jack/Desktop/HDD500/complete-videos/576x704_archive_1ps.mp4 -filter:v "setpts=40*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=32'" -y ${output_video}

# %%
timestamp=$(date +%Y-%m-%d_%H-%M-%S)
output_video='EXPERIMENT/lexica-warrior_'${timestamp}'.mp4'
echo ${output_video}

# %%
timestamp=$(date +%Y-%m-%d_%H-%M-%S)
output_video='EXPERIMENT/lexica-warrior_'${timestamp}'.mp4'
echo ${output_video}
ffmpeg -i /home/jack/Desktop/HDD500/complete-videos/576x704_archive_1ps.mp4 -filter:v "0:v]select='eq(t,0.1)+eq(t,0.5)+eq(t,0.9)',setpts=N/FRAME_RATE/TB" -an ${output_video}

# %%
ls -rant EXPERIMENT

# %%
output_video='/home/jack/Desktop/animate/20230506_215842644archived-images1.mp4'
ffmpeg -i ${output_video} -vf "mpdecimate,setpts=N/FRAME_RATE/TB" -an EXPERIMENT/animate.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
output_video='EXPERIMENT/lexica-warrior_video4.mp4'
ffmpeg -i ${output_video} -vf "mpdecimate,setpts=N/FRAME_RATE/TB" -an EXPERIMENT/lnm_faces_sp20_scd_select.mp4

# %%
ffmpeg -i input_video.mp4 -vf frei0r=diff0r -pix_fmt gray output_diff.mp4

# %%
ffmpeg -i input_video.mp4 -vf "select=gt(scene\,0.4),setpts=N/FRAME_RATE/TB" -af "aselect=gt(scene\,0.4),asetpts=N/SR/TB" output_scenes.mp4

# %%
’ve slowed the above video down so you can see each frame, but if you want the original video you can download it here. This consisted 47 faces/images, played one image per frame. In total it lasted 1.88 seconds and I needed to slow it down to at least x minutes, which is the length of the video.

Here is the code that I used

ffmpeg -i lnm_faces_original.mp4 -filter:v "setpts=40*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=400'" -y output.mp4

I’ll explain three of the important parts of this code.

SETPTS
The FFmpeg wiki has a good explanation of what setpts does:

To double the speed of the video, you can use:

ffmpeg -i input.mkv -filter:v "setpts=0.5*PTS" output.mkv

The filter works by changing the presentation timestamp (PTS) of each video frame. For example, if there are two successive frames shown at timestamps 1 and 2, and you want to speed up the video, those timestamps need to become 0.5 and 1, respectively. Thus, we have to multiply them by 0.5.

So, by using setpts=40*PTS I’m essentially slowing the video down by a factor of 40. For this video I took a guess at much I’d need to multiply the video of the faces to make it match the length of the video. If I wanted to be exact I’d need to use some maths and divide the frame count of the video (5268), divide it by the frame count of the face video (47) and use the output (112.085106383) as the PTS multiplier.

SCD
scd is probably the most important part of this code. It attempts to detect if there’s any scene changes and then not perform any motion interpolation on those frames. In this scenario, however, I want to interpolate between every frame, regardless of whether they appear to be part of the same “scene”. If you leave scd at the default of fdiff and scd_threshold at 5.0 ffmpeg tries to decide if there’s enough difference between frames. Here’s what that would’ve looked like:
