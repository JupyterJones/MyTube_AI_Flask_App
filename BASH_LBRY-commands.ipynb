# %%
lbrynet -h
# Out:
# Usage:  lbrynet [-v] [--api HOST:PORT] [--audio-encoder AUDIO_ENCODER]
#                 [--config FILE] [--ffmpeg-path FFMPEG_PATH]
#                 [--video-bitrate-maximum VIDEO_BITRATE_MAXIMUM]
#                 [--video-encoder VIDEO_ENCODER] [--video-scaler VIDEO_SCALER]
#                 [--volume-analysis-time VOLUME_ANALYSIS_TIME]
#                 [--volume-filter VOLUME_FILTER]
#                 COMMAND ...
#
# An interface to the LBRY Network.
#
# Options:
#   --help                Show this help message and exit.
#   -v, --version         Show lbrynet CLI version and exit.
#   --api HOST:PORT       Host name and port for lbrynet daemon API.
#   --audio-encoder AUDIO_ENCODER
#                         FFmpeg codec and parameters for the audio encoding.
#                         Example: libopus -b:a 128k
#   --config FILE         Path to configuration file.
#   --ffmpeg-path FFMPEG_PATH
#                         A list of places to check for ffmpeg and ffprobe.
# ...

# %%
lbrynet status
# Out:
# {
#   "background_downloader": {
#     "available_free_space_mb": 0,
#     "ongoing_download": false,
#     "running": true
#   },
#   "blob_manager": {
#     "connections": {
#       "incoming_bps": {},
#       "max_incoming_mbs": 0.022843,
#       "max_outgoing_mbs": 0.002929,
#       "outgoing_bps": {},
#       "total_incoming_mbs": 0.0,
#       "total_outgoing_mbs": 0.0,
#       "total_received": 4584,
#       "total_sent": 590
#     },
#     "finished_blobs": 1
#   },
#   "dht": {
#     "node_id": "41a7f7a2b9460ac29be3fc4d5a1da0fd3961b239d9abf1024dd3a7467956bf39d917d074efb4c2d1a22121b3d1ae546b",
#     "peers_in_routing_table": 17
#   },
#   "disk_space": {
#     "content_blobs_storage_used_mb": 0,
#     "published_blobs_storage_used_mb": 0,
#     "running": true,
#     "seed_blobs_storage_used_mb": 0,
#     "total_used_mb": 0
#   },
#   "ffmpeg_status": {
#     "analyze_audio_volume": true,
#     "available": true,
#     "which": "/usr/local/bin/ffmpeg"
#   },
# ...

# %%
lbrynet wallet -h
# Out:
# Usage:  lbrynet wallet COMMAND ...
#
# positional arguments:
#   COMMAND
#     add      Add existing wallet.
#     balance  Return the balance of a wallet
#     create   Create a new wallet.
#     decrypt  Decrypt an encrypted wallet, this will remove the wallet
#              password. The wallet must be unlocked to decrypt it
#     encrypt  Encrypt an unencrypted wallet with a password
#     export   Exports encrypted wallet data if password is supplied; otherwise
#              plain JSON.
#     import   Import wallet data and merge accounts and preferences. Data is
#              expected to be JSON if
#     list     List wallets.
#     lock     Lock an unlocked wallet
#     reconnect
#              Reconnects ledger network client, applying new configurations.
#     remove   Remove an existing wallet.
#     send     Send the same number of credits to multiple addresses using all
#              accounts in wallet to
# ...

# %%
lbrynet wallet add
# Out:
# Usage:
#             wallet_add (<wallet_id> | --wallet_id=<wallet_id>)
# : 1
