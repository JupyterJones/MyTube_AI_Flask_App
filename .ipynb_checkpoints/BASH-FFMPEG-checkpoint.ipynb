# %%
# Get the current date and time
current_datetime=$(date +"%Y-%m-%d_%H-%M-%S")
# Create a filename with the current date and time
filename="EXPERIMENT/_file_${current_datetime}.mp4"
VIDEO="EXP/alien_plant_life.mp4"
OUTPUT=EXPERIMENT/Set-5.mp4

#DIR=/mnt/HDD500/collections/newdownloads/512x512/
#DIR=/mnt/HDD500/collections/newdownloads/Discover_and_Generate_AI_Art_OpenArt_files/
#DIR=/mnt/HDD500/collections/art-nouveau/
#DIR=/mnt/HDD500/collections/640x640-alien/
#DIR=/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/leonardo-nouveau/
#DIR=/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/Lexica_Aperture_files/
#DIR=/mnt/HDD500/collections/512x768_pop-art/
#DIR=/mnt/HDD500/collections/alien/Lexicasearch_results_files/
#DIR=/mnt/HDD500/collections/alien/life/monsters/alien_plant_life/
#DIR="/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/leonardo-nouveau/princess_files/"
DIR="/home/jack/Desktop/HDD500/FLASK/static/alien_files/"

VIDEO="EXP/princess_final2.mp4"

FINAL="EXP/file_${current_datetime}.mp4"
MUSIC=/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3
ffmpeg -hide_banner -framerate 5 -i ${DIR}%05d.jpg -c:v libx264 -r 30 -pix_fmt yuv420p -y ${VIDEO}
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=5*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -t 58 -y ${filename}
TITLEimage=${DIR}00045.jpg
echo "Titlepage"${TITLEimage}
ffmpeg -i ${TITLEimage} -vf "drawtext=text='AI Chronicles ':fontfile=/home/jack/fonts/freesansbold.ttf:fontsize=45:fontcolor=white:x=(w-text_w)/2:y=((h-text_h)/2)-300" -y result_image_with_text.jpg
ffmpeg -loop 1 -i result_image_with_text.jpg -vf "fade=t=in:st=0:d=1:alpha=1, fade=t=out:st=3:d=1:alpha=1" -c:v libx264 -t 4 -y result_image_with_text.mp4
ffmpeg -i result_image_with_text.mp4 -i ${filename} -filter_complex "[0:v] [1:v] concat=n=2:v=1:a=0 [v]" -map "[v]" -t 59 -y EXP/titled.mp4
random_number=$(( RANDOM % 3000 + 100 ))
ffmpeg -ss 0 -i EXP/titled.mp4 -ss ${random_number} -i ${MUSIC} -map 0:v -map 1:a -c:v copy -c:a aac -shortest -y ${FINAL}
vlc ${FINAL}
# Out:
# Input #0, image2, from '/home/jack/Desktop/HDD500/FLASK/static/alien_files/%05d.jpg':
#   Duration: 00:00:23.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 512x666 [SAR 1:1 DAR 256:333], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x56119b3cf340] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x56119b32f1c0] using SAR=1/1
# [libx264 @ 0x56119b32f1c0] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x56119b32f1c0] profile High, level 3.0
# ...

# %%
# Get the current date and time
current_datetime=$(date +"%Y-%m-%d_%H-%M-%S")
# Create a filename with the current date and time
filename="EXPERIMENT/_file_${current_datetime}.mp4"
VIDEO=EXPERIMENT/Mixed_Images-5.mp4
OUTPUT=EXPERIMENT/Set-5.mp4
#/mnt/HDD500/collections/alien/life/monsters/alien_plant_life/"
DIR="/home/jack/Desktop/HDD500/FLASK/static/alien_files/"
# Get a list of all files in the directory
file_list=($(ls "${DIR}"*.jpg))
# Shuffle the file list randomly
shuffled_files=($(shuf -e "${file_list[@]}"))
# Generate a temporary file list with a limited number of files
temp_files=("${shuffled_files[@]:0:50}")
# Build the input argument for ffmpeg with the random file list
input_arg=""
for file in "${temp_files[@]}"; do
  input_arg+=" -i ${file}"
done
FINAL="EXPERIMENT/file_${current_datetime}.mp4"
MUSIC=/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3
ffmpeg -hide_banner -framerate 5 ${input_arg} -c:v libx264 -r 30 -pix_fmt yuv420p -y ${VIDEO}
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=5*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -t 58 -y ${filename}
TITLEimage=("${shuffled_files[@]:0:1}")
echo "Titlepage"${TITLEimage}
ffmpeg -i ${TITLEimage} -vf "drawtext=text='MIX AI Images':fontfile=/home/jack/fonts/freesansbold.ttf:fontsize=45:fontcolor=white:x=(w-text_w)/2:y=(h-text_h)/2" -y result_image_with_text.jpg
ffmpeg -hide_banner  -loop 1 -i result_image_with_text.jpg -vf "fade=t=in:st=0:d=1:alpha=1, fade=t=out:st=3:d=1:alpha=1" -c:v libx264 -t 4 -y result_image_with_text.mp4
ffmpeg -hide_banner  -i result_image_with_text.mp4 ${filename} -filter_complex "[0:v] [1:v] concat=n=2:v=1:a=0 [v]" -map "[v]" -t 59 -y EXPERIMENT/titled.mp4
random_number=$(( RANDOM % 3000 + 100 ))
ffmpeg -hide_banner  -ss 0 -i EXPERIMENT/titled.mp4 -ss ${random_number} -i ${MUSIC} -map 0:v -map 1:a -c:v copy -c:a aac -shortest -y ${FINAL}
vlc ${FINAL}

# %%
ls /home/jack/Desktop/HDD500/collections/Borders/
# Out:
# 01-print.png           frameArtnouveau01.png
# 02-print.png           frameArtnouveau02.png
# 03-print.png           frame-lite.png
# 04-print.png           frame.png
# 05-print.png           frames.png
# 06-print.png           golden-frame.png
# 07-print.png           gold_nouveau_black_ImageBot.png
# 08-print.png           gold_nouveau_black.png
# 09-print.png           gold_nouveau_border.png
# 1bottomcar.png         gold_nouveau.png
# 1_frame-lite.png       leopard-print.png
# 1topcar.png            lined-frame.png
# abstract-print.png     nouveau-black-frame1.png
# Anger.png              nouveau-black-frame.png
# beige-blur-frame.png   nouveau-red-frame.png
# black-blur-frame2.png  perferations+.png
# black-blur-frame.png   perferations.png
# border2.png            rocks-print.png
# border.png             tensorlow-frames.png
# canvas_lite_02.png     usal-perferations.png
# canvas_lite.png        usa-perferations.png
# canvas.png             usar-perferations.png
# ...

# %%
locate *.mp4 >>list.mp4

# %%
cp /mnt/HDD500/FLASK/static/transparent_borders/*.png /home/jack/Desktop/HDD500/collections/Borders/

# %%
locate frame.png
# Out:
# /home/jack/.cache/inkscape/icons/16x16/text-flow-into-frame.png
# /home/jack/Desktop/content/env/lib/python3.8/site-packages/PyQt5/Qt5/qml/QtQuick/Controls/Styles/Base/images/focusframe.png
# /home/jack/Desktop/content/env/lib/python3.8/site-packages/PyQt5/Qt5/qml/QtQuick/Dialogs/images/sunken_frame.png
# /home/jack/Desktop/thumbs/beige-blur-frame.png.thumb.png
# /home/jack/Desktop/thumbs/black-blur-frame.png.thumb.png
# /home/jack/Desktop/thumbs/frame.png.thumb.png
# /home/jack/Desktop/thumbs/golden-frame.png.thumb.png
# /home/jack/Desktop/thumbs/lined-frame.png.thumb.png
# /home/jack/Desktop/thumbs/nouveau-black-frame.png.thumb.png
# /home/jack/Desktop/thumbs/nouveau-red-frame.png.thumb.png
# /home/jack/Desktop/thumbs/white-blur-frame.png.thumb.png
# /home/jack/Desktop/thumbs/wood-blur-frame.png.thumb.png
# /home/jack/Documents/gimp-2.8.10/devel-docs/libgimpwidgets/html/gimp-frame.png
# /home/jack/Documents/gimp-2.8.10/devel-docs/libgimpwidgets/images/gimp-frame.png
# ...

# %%
ffmpeg -i /home/jack/Desktop/HDD500/collections/moving_borders/transparent.mp4  -vf "colorkey=0x00FF00:0.1:0.1,format=yuva420p" -c:v ffv1 -an -y /home/jack/Desktop/HDD500/collections/moving_borders/greenscreen_alpha.mov
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i /mnt/HDD500/collections/Prodia-AI_Art_and_Music_files/joined_with_intro.mp4 -i /home/jack/Desktop/HDD500/collections/moving_borders/transparent.mp4 -filter_complex "[0:v][1:v]overlay=0:0[outv]" -map "[outv]" -map 0:a -c:v libx264 -c:a copy output.mp4

# %%
ffmpeg -i /home/jack/Desktop/HDD500/collections/moving_borders/multicolor.gif -loop 0 -c:v libvpx-vp9 -pix_fmt yuva420p -metadata:s:v:0 alpha_mode="1" -t 60 -y /home/jack/Desktop/HDD500/collections/moving_borders/transparent.mp4
ffmpeg -i /mnt/HDD500/collections/Prodia-AI_Art_and_Music_files/joined_with_intro.mp4 -i /home/jack/Desktop/HDD500/collections/moving_borders/transparent.mp4 -filter_complex "[0:v][1:v]overlay=0:0[outv]" -map "[outv]" -map 0:a -c:v libx264 -c:a copy -y output.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
!ffmpeg -i /home/jack/Desktop/HDD500/collections/moving_borders/multicolorgreen59.mp4 -vf "alphaextract" -c:v ffv1 -an /home/jack/Desktop/HDD500/collections/moving_borders/greenscreen_alpha.mov
# Out:
# ffmpeg -i /mnt/HDD500/collections/Prodia-AI_Art_and_Music_files/joined_with_intro.mp4 -i /home/jack/Desktop/HDD500/collections/moving_borders/transparent.mp4 -filter_complex "[0:v][1:v]overlay=0:0[outv]" -map "[outv]" -map 0:a -c:v libx264 -c:a copy -y output.mp4 -i /home/jack/Desktop/HDD500/collections/moving_borders/multicolorgreen59.mp4 -vf "alphaextract" -c:v ffv1 -an greenscreen_alpha.mov -i /home/jack/Desktop/HDD500/collections/moving_borders/multicolorgreen59.mp4 -vf "alphaextract" -c:v ffv1 -an /home/jack/Desktop/HDD500/collections/moving_borders/greenscreen_alpha.mov
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i /home/jack/Desktop/HDD500/collections/moving_borders/multicolor.gif -c:v libvpx-vp9 -pix_fmt yuva420p -metadata:s:v:0 alpha_mode="1" -t 60 -y /home/jack/Desktop/HDD500/collections/moving_borders/transparent.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i /home/jack/Desktop/HDD500/collections/moving_borders/multicolor.gif -c:v libvpx-vp9 -pix_fmt yuva420p -metadata:s:v:0 alpha_mode="1" -auto-alt-ref 0 -t 25 -y /home/jack/Desktop/HDD500/collections/moving_borders/transparent.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
# Get the current date and time
current_datetime=$(date +"%Y-%m-%d_%H-%M-%S")
# Create a filename with the current date and time
filename="EXPERIMENT/_file_${current_datetime}.mp4"
VIDEO=EXPERIMENT/Mixed_Images-5.mp4
OUTPUT=EXPERIMENT/Set-5.mp4
#DIR=/mnt/HDD500/collections/newdownloads/512x512/
#DIR=/mnt/HDD500/collections/newdownloads/Discover_and_Generate_AI_Art_OpenArt_files/
#DIR=/mnt/HDD500/collections/art-nouveau/
#DIR=/mnt/HDD500/collections/640x640-alien/
#DIR="/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/leonardo-nouveau/"
DIR="/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/AI_Celebrities/"
#DIR=/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/Lexica_Aperture_files/
#DIR=/mnt/HDD500/collections/512x768_pop-art/
#DIR=/mnt/HDD500/collections/alien/Lexicasearch_results_files/
#DIR="/mnt/HDD500/collections/alien/life/monsters/alien_plant_life/"
#DIR="/mnt/HDD500/collections/alien/life/plant/Lexica_files/"
#DIR="/mnt/HDD500/collections/alien_flowers/"
VIDEO="EXPERIMENT/XXXX1.mp4"
directory_name=$(basename "${DIR}")
# Find all JPG files in the directory
jpg_files=("${DIR}"*.jpg)
# Get the total number of JPG files
num_files=${#jpg_files[@]}
# Generate a random index
random_index=$(( RANDOM % num_files ))
# Select the random file
random_file="${jpg_files[random_index]}"
# Apply the text overlay on the random image
ffmpeg -hide_banner -i "${random_file}" -vf "drawtext=text='${directory_name}':fontfile=/home/jack/fonts/freesansbold.ttf:fontsize=45:fontcolor=white:x=(w-text_w)/2:y=(h-text_h)/2" -y EXPERIMENT/result_image_with_text.jpg
# Get the directory name
#directory_name=$(basename "${DIR}")
# Find all JPG files in the directory
jpg_files=("${DIR}"*.jpg)
# Get the total number of JPG files
num_files=${#jpg_files[@]}
# Generate a random index
random_index=$(( RANDOM % num_files ))
# Select the random file
random_file="${jpg_files[random_index]}"
# Apply the text overlay on the random image
ffmpeg -hide_banner -i "${random_file}" -vf "drawtext=text='${directory_name}':fontfile=/home/jack/fonts/freesansbold.ttf:fontsize=45:fontcolor=white:x=(w-text_w)/2:y=(h-text_h)/2" -y EXPERIMENT/result_image_with_text.jpg
TITLEimage="EXPERIMENT/result_image_with_text.jpg"
# Use a glob pattern to match the image files in the directory
file_list=(${DIR}*.jpg)
# Shuffle the file list randomly
shuffled_files=($(shuf -e "${file_list[@]}"))
# Build the input argument for ffmpeg with the shuffled file list
input_arg=""
for file in "${shuffled_files[@]}"; do
  input_arg+=" -loop 1 -t 00:00:00.2 -i ${file}"
done
# Run ffmpeg with the shuffled file list
ffmpeg -hide_banner ${input_arg} -filter_complex "concat=n=${#shuffled_files[@]}:v=1:a=0" -c:v libx264 -r 30 -pix_fmt yuv420p -t 58 -y ${VIDEO}
FINAL="EXPERIMENT/file_${current_datetime}.mp4"
MUSIC=/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3
#ffmpeg -hide_banner -framerate 5 -i ${DIR}%05d.jpg -c:v libx264 -r 30 -pix_fmt yuv420p -y ${VIDEO}
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=5*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -t 58 -y ${filename}
ffmpeg -hide_banner -loop 1 -i EXPERIMENT/result_image_with_text.jpg -vf "fade=t=in:st=0:d=1:alpha=1, fade=t=out:st=3:d=1:alpha=1" -c:v libx264 -t 4 -y EXPERIMENT/result_image_with_text.mp4
ffmpeg -i EXPERIMENT/result_image_with_text.mp4 -i ${filename} -filter_complex "[0:v] [1:v] concat=n=2:v=1:a=0 [v]" -map "[v]" -t 59 -y EXPERIMENT/titled.mp4
random_number=$(( RANDOM % 3000 + 100 ))
ffmpeg -ss 0 -i EXPERIMENT/titled.mp4 -ss ${random_number} -i ${MUSIC} -map 0:v -map 1:a -c:v copy -c:a aac -shortest -y ${FINAL}
vlc ${FINAL}

# %%
#!/bin/bash

DIR="/mnt/HDD500/collections/alien_flowers/"
# Get the directory name
directory_name=$(basename "${DIR}")
# Find all JPG files in the directory
jpg_files=("${DIR}"*.jpg)
# Get the total number of JPG files
num_files=${#jpg_files[@]}
# Generate a random index
random_index=$(( RANDOM % num_files ))
# Select the random file
random_file="${jpg_files[random_index]}"
# Apply the text overlay on the random image
ffmpeg -hide_banner -i "${random_file}" -vf "drawtext=text='${directory_name}':fontfile=/home/jack/fonts/freesansbold.ttf:fontsize=45:fontcolor=white:x=(w-text_w)/2:y=(h-text_h)/2" -y EXPERIMENT/result_image_with_text.jpg

# %% [markdown]
# # Write two lines of text on an Image

# %%
#DIR="/mnt/HDD500/collections/alien_flowers/"
DIR="/home/jack/Desktop/HDD500/collections/Beautiful_Backgrounds2/"
directory_name=$(basename "${DIR}")
echo ${directory_name}
# Find all JPG files in the directory
jpg_files=$(find "${DIR}" -type f -name "*.jpg")
# Shuffle the file list and select one random file
random_file=$(shuf -e "${jpg_files[@]}" | head -n 1)
ffmpeg -hide_banner -i ${random_file} -vf "drawtext=text="Top":fontfile=/home/jack/fonts/freesansbold.ttf:fontsize=45:fontcolor=white:x=(w-text_w)/2:y=(h-text_h)/2+50,drawtext=text="Bottom":fontfile=/home/jack/fonts/freesansbold.ttf:fontsize=45:fontcolor=white:x=(w-text_w)/2:y=(h-text_h)/2" -y EXP/result_image_with_text.jpg

# %% [markdown]
# # Make a Video from a directory of images

# %%
#!/bin/bash

#DIR="/mnt/HDD500/collections/alien/life/monsters/alien_plant_life/"
#VIDEO="EXP/alien_plant_life.mp4"

DIR="/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/leonardo-nouveau/princess_files/"
VIDEO="EXP/princess.mp4"
# Use a glob pattern to match the image files in the directory
file_list=(${DIR}*.jpg)
# Shuffle the file list randomly
shuffled_files=($(shuf -e "${file_list[@]}"))
# Build the input argument for ffmpeg with the shuffled file list
input_arg=""
for file in "${shuffled_files[@]}"; do
  input_arg+=" -loop 1 -t 00:00:00.1 -i ${file}"
done
# Run ffmpeg with the shuffled file list
ffmpeg -hide_banner ${input_arg} -filter_complex "concat=n=${#shuffled_files[@]}:v=1:a=0" -c:v libx264 -r 30 -pix_fmt yuv420p -t 58 -y ${VIDEO}
vlc ${VIDEO}
# Out:
# Input #0, image2, from '/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/leonardo-nouveau/princess_files/RPG_40_Brillant_colors_abstact_splatter_art_sticker_Egy_017.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 35182 kb/s
#     Stream #0:0: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 512x666 [SAR 1:1 DAR 256:333], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Input #1, image2, from '/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/leonardo-nouveau/princess_files/DreamShaper_32_Brillant_colors_abstact_splatter_art_sti_003.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 39415 kb/s
#     Stream #1:0: Video: mjpeg (Baseline), yuvj444p(pc, bt470bg/unknown/unknown), 512x666 [SAR 1:1 DAR 256:333], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Input #2, image2, from '/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/leonardo-nouveau/princess_files/Deliberate_11_Brillant_colors_abstact_splatter_art_stic_005.jpg':
# ...

# %%
# Get the current date and time
current_datetime=$(date +"%Y-%m-%d_%H-%M-%S")
# Create a filename with the current date and time
filename="EXP/_file_${current_datetime}.mp4"
VIDEO="EXP/alien_plant_life.mp4"
OUTPUT=EXPERIMENT/Set-5.mp4

#DIR=/mnt/HDD500/collections/newdownloads/512x512/
#DIR=/mnt/HDD500/collections/newdownloads/Discover_and_Generate_AI_Art_OpenArt_files/
#DIR=/mnt/HDD500/collections/art-nouveau/
#DIR=/mnt/HDD500/collections/640x640-alien/
#DIR=/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/leonardo-nouveau/
#DIR=/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/Lexica_Aperture_files/
#DIR=/mnt/HDD500/collections/512x768_pop-art/
#DIR=/mnt/HDD500/collections/alien/Lexicasearch_results_files/
#DIR=/mnt/HDD500/collections/alien/life/monsters/alien_plant_life/
DIR="/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/leonardo-nouveau/princess_files/"

# Use a glob pattern to match the image files in the directory
file_list=(${DIR}*.jpg)
# Shuffle the file list randomly
shuffled_files=($(shuf -e "${file_list[@]}"))
# Build the input argument for ffmpeg with the shuffled file list
input_arg=""
for file in "${shuffled_files[@]}"; do
  input_arg+=" -loop 1 -t 00:00:00.1 -i ${file}"
done
# Run ffmpeg with the shuffled file list
FINAL="EXP/file_${current_datetime}.mp4"
MUSIC=/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3
ffmpeg -hide_banner -framerate 5 -i ${input_arg} -c:v libx264 -r 30 -pix_fmt yuv420p -y ${VIDEO}
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=5*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -t 58 -y ${filename}
TITLEimage=${DIR}00045.jpg
echo "Titlepage"${TITLEimage}
ffmpeg -i ${TITLEimage} -vf "drawtext=text='AI Aqua-Images':fontfile=/home/jack/fonts/freesansbold.ttf:fontsize=45:fontcolor=white:x=(w-text_w)/2:y=(h-text_h)/2" -y result_image_with_text.jpg
ffmpeg -loop 1 -i result_image_with_text.jpg -vf "fade=t=in:st=0:d=1:alpha=1, fade=t=out:st=3:d=1:alpha=1" -c:v libx264 -t 4 -y result_image_with_text.mp4
ffmpeg -i result_image_with_text.mp4 -i ${filename} -filter_complex "[0:v] [1:v] concat=n=2:v=1:a=0 [v]" -map "[v]" -t 59 -y EXP/titled.mp4
random_number=$(( RANDOM % 3000 + 100 ))
ffmpeg -ss 0 -i EXP/titled.mp4 -ss ${random_number} -i ${MUSIC} -map 0:v -map 1:a -c:v copy -c:a aac -shortest -y ${FINAL}
vlc ${FINAL}
# Out:
# -loop: No such file or directory
#
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'EXP/alien_plant_life.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:02:18.60, start: 0.000000, bitrate: 1776 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x640 [SAR 1:1 DAR 1:1], 1773 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55aa5d9146c0] using SAR=1/1
# [libx264 @ 0x55aa5d9146c0] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x55aa5d9146c0] profile High, level 3.0
# ...

# %%
mkdir EXP

# %%
#!/bin/bash

DIR="path/to/images/"
VIDEO="output.mp4"

# Get a list of all files in the directory
file_list=($(ls "${DIR}"*.jpg))

# Shuffle the file list randomly
shuffled_files=($(shuf -e "${file_list[@]}"))

# Generate a temporary file list with a limited number of files
temp_files=("${shuffled_files[@]:0:10}")

# Build the input argument for ffmpeg with the random file list
input_arg=""
for file in "${temp_files[@]}"; do
  input_arg+=" -i ${file}"
done

# Run ffmpeg with the random file list
ffmpeg -hide_banner ${input_arg} -c:v libx264 -r 30 -pix_fmt yuv420p -y ${VIDEO}

# %%
#!/bin/bash

DIR="/mnt/HDD500/collections/alien/life/monsters/alien_plant_life/"
VIDEO="EXPERIMENT/XXXX.mp4"

# Get a list of all files in the directory
file_list=($(ls "${DIR}"*.jpg))

# Shuffle the file list randomly
shuffled_files=($(shuf -e "${file_list[@]}"))

# Build the input argument for ffmpeg with the random file list
input_arg=""
for file in "${shuffled_files[@]}"; do
  input_arg+=" -loop 1 -t 5 -i ${file}"
done

# Run ffmpeg with the random file list
ffmpeg -hide_banner ${input_arg} -filter_complex "concat=n=${#shuffled_files[@]}:v=1:a=0" -c:v libx264 -r 30 -pix_fmt yuv420p -y ${VIDEO}

vlc ${VIDEO}

# %%
#!/bin/bash
DIR="/mnt/HDD500/collections/alien/life/monsters/alien_plant_life/"
VIDEO="EXPERIMENT/XXXX.mp4"
# Get a list of all files in the directory
file_list=($(ls "${DIR}"*.jpg))
# Shuffle the file list randomly
shuffled_files=($(shuf -e "${file_list[@]}"))
# Build the input argument for ffmpeg with the random file list
input_arg=""
for file in "${shuffled_files[@]}"; do
  input_arg+=" -i ${file}"
done
# Run ffmpeg with the random file list
#ffmpeg -hide_banner -framerate 5  ${input_arg}  -c:v libx264 -r 30 -pix_fmt yuv420p -y ${VIDEO}
ffmpeg -hide_banner ${input_arg} -c:v libx264 -r 30 -pix_fmt yuv420p -y ${VIDEO}

vlc ${VIDEO}

# %%
#!/bin/bash

DIR="/mnt/HDD500/collections/alien/life/monsters/alien_plant_life/"

# Get a list of all files in the directory
file_list=($(ls "${DIR}"*.jpg))

# Shuffle the file list randomly
shuffled_files=($(shuf -e "${file_list[@]}"))

# Build the input argument for ffmpeg with the random file list
input_arg=""
for file in "${shuffled_files[@]}"; do
  input_arg+=" -i ${file}"
done

# %%
TITLEimage=("${shuffled_files[@]:0:1}")
echo ${temp_files}

# %%
DIR=/mnt/HDD500/collections/alien/life/monsters/alien_plant_life/
# Get a list of all files in the directory
file_list=($(ls "${DIR}"*.jpg))
# Shuffle the file list randomly
shuffled_files=($(shuf -e "${file_list[@]}"))
# Build the input argument for ffmpeg with the random file list
input_arg=""
for file in "${shuffled_files[@]}"; do
  input_arg+=" -i ${file}"
done

# Run ffmpeg with the random file list
ffmpeg -hide_banner ${input_arg} -c:v libx264 -r 30 -pix_fmt yuv420p -y ${VIDEO}

In this modified script, the temp_files variable is no longer used. Instead, the entire shuffled file list (shuffled_files) is used to build the input argument for ffmpeg. This ensures that all files in the directory are included in the random sequence.

Again, make sure to replace "path/to/images/" with the actual path to your image directory and "output.mp4" with the desired output video filename.

# %%
#!/bin/bash

DIR=/mnt/HDD500/collections/alien/life/monsters/alien_plant_life/
# Get a list of all files in the directory
file_list=($(ls "${DIR}"*.jpg))
# Shuffle the file list randomly
shuffled_files=($(shuf -e "${file_list[@]}"))
# Generate a temporary file list with a limited number of files
temp_files=("${shuffled_files[@]:0:50}")
# Build the input argument for ffmpeg with the random file list
input_arg=""
for file in "${temp_files[@]}"; do
  input_arg+=" -i ${file}"
done

# Run ffmpeg with the random file list
#ffmpeg -hide_banner ${input_arg} -c:v libx264 -r 30 -pix_fmt yuv420p -y ${VIDEO}

# %%
#!/bin/bash

DIR="/mnt/HDD500/collections/alien/life/monsters/alien_plant_life/"

# Get a list of all files in the directory
file_list=($(ls "${DIR}"*.jpg))

# Shuffle the file list randomly
shuffled_files=($(shuf -e "${file_list[@]}"))

# Generate a temporary file list with a limited number of files
temp_files=("${shuffled_files[@]:0:50}")

# Build the input argument for ffmpeg with the random file list
input_arg=""
for file in "${temp_files[@]}"; do
  input_arg+=" -i ${file}"
done

# %%
# Get the current date and time
current_datetime=$(date +"%Y-%m-%d_%H-%M-%S")
# Create a filename with the current date and time
filename="EXPERIMENT/_file_${current_datetime}.mp4"
VIDEO=EXPERIMENT/Mixed_Images-5.mp4
OUTPUT=EXPERIMENT/Set-5.mp4
#DIR=/mnt/HDD500/collections/newdownloads/512x512/
#DIR=/mnt/HDD500/collections/newdownloads/Discover_and_Generate_AI_Art_OpenArt_files/
#DIR=/mnt/HDD500/collections/art-nouveau/
#DIR=/mnt/HDD500/collections/640x640-alien/
#DIR=/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/leonardo-nouveau/
#DIR=/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/Lexica_Aperture_files/
#DIR=/mnt/HDD500/collections/512x768_pop-art/
#DIR=/mnt/HDD500/collections/alien/Lexicasearch_results_files/
DIR="/mnt/HDD500/collections/alien/life/monsters/alien_plant_life/"

# Get a list of all files in the directory
file_list=($(ls "${DIR}"*.jpg))

# Shuffle the file list randomly
shuffled_files=($(shuf -e "${file_list[@]}"))

# Generate a temporary file list with a limited number of files
temp_files=("${shuffled_files[@]:0:50}")

# Build the input argument for ffmpeg with the random file list
input_arg=""
for file in "${temp_files[@]}"; do
  input_arg+=" -i ${file}"
done

FINAL="EXPERIMENT/file_${current_datetime}.mp4"
MUSIC=/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3
ffmpeg -hide_banner -framerate 5 ${input_arg} -c:v libx264 -r 30 -pix_fmt yuv420p -y ${VIDEO}
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=5*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -t 58 -y ${filename}
TITLEimage=("${shuffled_files[@]:0:1}")
echo "Titlepage"${TITLEimage}
ffmpeg -i ${TITLEimage} -vf "drawtext=text='MIX AI Images':fontfile=/home/jack/fonts/freesansbold.ttf:fontsize=45:fontcolor=white:x=(w-text_w)/2:y=(h-text_h)/2" -y result_image_with_text.jpg
ffmpeg -loop 1 -i result_image_with_text.jpg -vf "fade=t=in:st=0:d=1:alpha=1, fade=t=out:st=3:d=1:alpha=1" -c:v libx264 -t 4 -y result_image_with_text.mp4
ffmpeg -i result_image_with_text.mp4 ${filename} -filter_complex "[0:v] [1:v] concat=n=2:v=1:a=0 [v]" -map "[v]" -t 59 -y EXPERIMENT/titled.mp4
random_number=$(( RANDOM % 3000 + 100 ))
ffmpeg -ss 0 -i EXPERIMENT/titled.mp4 -ss ${random_number} -i ${MUSIC} -map 0:v -map 1:a -c:v copy -c:a aac -shortest -y ${FINAL}
vlc ${FINAL}

# %%
#!/bin/bash

# Get the current date and time
current_datetime=$(date +"%Y-%m-%d_%H-%M-%S")

# Create a filename with the current date and time
filename="file_${current_datetime}.mp4"

# Save some content to the file
echo "This is a sample file." > "$filename"

echo "File saved as: $filename"

# %%
ls /mnt/HDD500/collections/640x640-alien/

# %%
/home/jack/Desktop/HDD500/Downloads/00de3/butterflies/frog/leonardo.ai_files/SUPER_EFFECT_Output.mkv

# %%
#mkdir tinydir
cp square/*004*.jpg tinydir
ls tinydir

# %% [markdown]
# # Rename in format 00001.jpg, 00002.jpg, 00003.jpg, etc

# %%
ls tinydir
echo "---------------------"
counter=1
for file in tinydir/*.jpg; do
    if [ -f "$file" ]; then
        mv "$file" "tinydir/$(printf '%05d' $counter).jpg"
        ((counter++))
    fi
done
echo "---------------------"
ls tinydir

# %%
ffmpeg -hide_banner -framerate 5 -i /home/jack/Desktop/HDD500/Downloads/00de3/butterflies/frog/leonardo.ai_files/%05d.jpg -c:v libx264 -r 30 -pix_fmt yuv420p EXPERIMENT/leonardo_frog-5.mp4

# %%
vlc EXPERIMENT/leonardo_frog-5.mp4

# %%
ls -rant EXPERIMENT/*.mp4

# %%
#vlc tinydir/output25.mp4
vlc tinydir/search_param_32.mp4

# %%
VIDEO=/home/jack/Desktop/HDD500/0WORKSHOP-with-NOTEBOOKS/EXPERIMENT/leonardo_frog-5.mp4

# %%
VIDEO=/home/jack/Desktop/HDD500/0WORKSHOP-with-NOTEBOOKS/EXPERIMENT/SUPER_EFFECT_Output.mkv
echo ${VIDEO}

# %%
VIDEO=/home/jack/Desktop/ProcessDirectory/uploads/SUPER_EFFECT_Output.mkv
echo ${VIDEO}

# %%
#And with the slightly ridiculous value of 2000:
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=40*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -y /home/jack/Desktop/ProcessDirectory/uploads/SE.mp4

#The biggest difference is clearly between setting the search_param from 32 to 400. At 2000 there’s only minor differences, though this may change depending on your source input.

# %%
vlc /home/jack/Desktop/ProcessDirectory/uploads/SE.mp4

# %%
vlc EXPERIMENT/frog-5_param10-search200.mp4

# %%
vlc /home/jack/Desktop/ProcessDirectory/uploads/SE.mp4

# %%
VIDEO="/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/EXPvideo/Vid_image_list20230527_191724096.mp4"

# %%
VIDEO="/home/jack/Desktop/HDD500/0WORKSHOP-with-NOTEBOOKS/EXPvideo/Vid_image_list20230527_191724096.mp4"

# %%
#And with the slightly ridiculous value of 2000:
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=8*PTS,minterpolate='fps=24:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -y EXPvideo/setpoints8-200.mp4
# Out:
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/jack/Desktop/HDD500/0WORKSHOP-with-NOTEBOOKS/EXPvideo/Vid_image_list20230527_191724096.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:50.00, start: 0.000000, bitrate: 816 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x512, 814 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55aeb4f0d5c0] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x55aeb4f0d5c0] profile High, level 3.0
# ...

# %%
#And with the slightly ridiculous value of 2000:
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=15*PTS,minterpolate='fps=24:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -y EXPvideo/setpoints15-200.mp4

# %%
ffmpeg -i EXPvideo/output_15-200.mp4 -vf "mpdecimate=hi=0.2:lo=0.2" -c:v libx264 -crf 10 -c:a copy EXPvideo/output_a.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
#!/bin/bash

# Create a new directory for the output files
#mkdir /mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/leonardo-nouveau/trees_files/output_directory

# Loop through each JPG file in the directory
for file in /mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/leonardo-nouveau/trees_files/*.jpg; do
    # Get the filename without the extension
    filename=$(basename "$file" .jpg)
    # Lighten the image and save it to the output directory
    convert "$file" -modulate 120 "/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/leonardo-nouveau/trees_files/output_directory/$filename.jpg"
done

# %%
ffmpeg -i EXPvideo/output_a.mp4 -vf "mpdecimate=hi=0.2:lo=0.2" -c:v libx264 -crf 10 -c:a copy EXPvideo/output_b.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i EXPvideo/output_b.mp4 -vf "mpdecimate=hi=0.2:lo=0.2" -c:v libx264 -crf 10 -c:a copy EXPvideo/output_c.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i EXPvideo/setpoints8-200.mp4 -vf "mpdecimate=hi=0.2:lo=0.2" -c:v libx264 -crf 10 -c:a copy EXPvideo/output_8-200.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i EXPvideo/setpoints8-200.mp4 -vf "mpdecimate=hi=0.2:lo=0.2" -c:v libx264 -crf 10 -c:a copy EXPvideo/output_8-200.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i EXPvideo/setpoints15-200.mp4 -vf "mpdecimate=hi=0.2:lo=0.2" -c:v libx264 -crf 10 -c:a copy EXPvideo/output_15-200.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i EXPvideo/shortfrogs-setpoints25-200.mp4 -vf "mpdecimate=hi=0.5:lo=0.5" -c:v libx264 -crf 23 -c:a copy EXPvideo/output-5-5.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i EXPvideo/shortfrogs-setpoints25-200.mp4 -vf "mpdecimate=hi=0.75:lo=0.75" -c:v libx264 -crf 23 -c:a copy EXPvideo/output-75.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i EXPvideo/shortfrogs-setpoints25-200.mp4 -vf "mpdecimate=hi=1:lo=1" -c:v libx264 -crf 23 -c:a copy EXPvideo/output11.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i EXPvideo/shortfrogs-setpoints25-200.mp4 -vf "mpdecimate" -c:v libx264 -crf 23 -c:a copy EXPvideo/output.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i EXPvideo/shortfrogs-setpoints25-200.mp4 -vf "mpdecimate=hi=3:lo=1" -c:v libx264 -preset medium -crf 23 -c:a copy -y EXPvideo/frog-setpoints25-200_mpdecimate=hi=3:lo=1.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i EXPvideo/shortfrogs-setpoints25-200.mp4 -vf "mpdecimate=hi=3:lo=1" -c:v libx264 -preset medium -crf 23 -c:a copy -y EXPvideo/frog-setpoints25-200_mpdecimate=hi=3:lo=1.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i EXPvideo/shortfrogs-setpoints25-200.mp4 -vf "mpdecimate=hi=3:lo=1" -c:v libx264 -preset medium -crf 23 -c:a copy -y EXPvideo/frog-setpoints25-200_mpdecimate=hi=3:lo=1.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i EXPvideo/shortfrogs-setpoints25-200.mp4 -vf "mpdecimate=hi=3:lo=1" -c:v libx264 -preset medium -crf 23 -c:a copy -y EXPvideo/frog-setpoints25-200_mpdecimate=hi=3:lo=1.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
ffmpeg -i EXPvideo/frog-setpoints25-200_mpdecimate=hi=3:lo=1.mp4 -vf "mpdecimate" -c:v libx264 -preset medium -crf 23 -c:a copy -y EXPvideo/mpdecimate.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
In the command above, the mpdecimate filter is applied to the video using the following options:

    hi: The maximum number of identical frames allowed in a row. Any frames beyond this limit will be considered duplicate frames and removed from the output. In this case, we set hi=5 to limit the number of identical frames to 5.

    lo: The minimum number of frames that must separate two identical frames to prevent them from being considered duplicates. In this case, we set lo=1 to allow identical frames that are separated by at least one different frame.

The output video is encoded using the libx264 codec with a medium preset and a CRF (Constant Rate Factor) of 23. The audio stream is copied directly from the input to the output without any modification (-c:a copy).

# %%
FROGS

# %%
ffmpeg -i EXPERIMENT/frogs.mp4 -vf "mpdecimate" -f null -

# %%
ffmpeg -i input.mp4 -vf "mpdecimate" -c:v libx264 -crf 23 -c:a copy output.mp4

# %% [markdown]
# # This got rid of duplicate frames

# %%
ffmpeg -hide_banner -i EXPERIMENT/shortfrogs.mp4 -filter:v "select='gt(scene\,0.01)',setpts=N/FRAME_RATE/TB" -an -vsync 0 EXPERIMENT/shortfrogs2.mp4

# %%
#And with the slightly ridiculous value of 2000:
ffmpeg -hide_banner -i EXPERIMENT/shortfrogs2.mp4 -filter:v "setpts=10*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=32'" -y EXPERIMENT/shortfrogs-setpoints10.mp4

#The biggest difference is clearly between setting the search_param from 32 to 400. At 2000 there’s only minor differences, though this may change depending on your source input.

# %%
#And with the slightly ridiculous value of 2000:
ffmpeg -hide_banner -i EXPERIMENT/shortfrogs2.mp4 -filter:v "setpts=4*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -y EXPERIMENT/shortfrogs-setpoints4-200.mp4

#The biggest difference is clearly between setting the search_param from 32 to 400. At 2000 there’s only minor differences, though this may change depending on your source input.

# %%
ffmpeg -i input.mp4 -vf "select='mod(n,5)=0',setpts=N/w/TB" output.mp4

# %%
ffmpeg -i EXPERIMENT/shortfrogs-setpoints4-200.mp4 -vf "select='not(mod(n\,1.5))',setpts=N/FRAME_RATE*2/TB" -y EXPERIMENT/shortfrogs-setpoints4-200every1t2.mp4

# %%
ffmpeg -i EXPERIMENT/shortfrogs-setpoints4-200.mp4 -vf "select='not(mod(n\,5))',setpts=N/FRAME_RATE/TB" -y EXPERIMENT/shortfrogs-setpoints4-200every2.mp4

# %%
# Duplicates EVERY frame
ffmpeg -hide_banner -i EXPERIMENT/shortfrogs-setpoints4-200.mp4 -vf "select='not(mod(n\,5))',setpts=N/2/TB" EXPERIMENT/shortfrogs-setpoints4-200every2.mp4

# %%
vlc EXPERIMENT/shortfrogs-setpoints4-200every2.mp4

# %%
vlc EXPERIMENT/shortfrogs-setpoints10.mp4

# %%
ffmpeg -i shortfrogs.mp4 -filter:v "select='gt(scene\,0.01)',setpts=N/FRAME_RATE/TB" -an -vsync 0 frogoutput_video.mp4

# %%
ffmpeg -i EXPERIMENT/frogs.mp4 -vf "mpdecimate" -map 0:v:0 -c copy -f null - 2>&1 | grep -c DUP=

# %%
ffmpeg -i EXPERIMENT/frogs.mp4 -vf mpdecimate -c:v libx264 -preset medium -crf 23 -c:a copy EXPERIMENT/shortfrogs.mp4

# %%
ffmpeg -hide_banner -i EXPERIMENT/frogs.mp4 -vf "mpdecimate" -c:v copy -f null -

# %%
ffmpeg -i EXPERIMENT/frogs.mp4 -vf "mpdecimate" -c:v libx264 -crf 23 -c:a copy EXPERIMENT/frogoutput.mp4

# %%
!vlc EXPERIMENT/frog-search200_mpdecimate=hi=3:lo=1.mp4

# %%
ffmpeg -i EXPERIMENT/frog-5_param10-search200.mp4 -vf "mpdecimate=hi=1:lo=1" -c:v libx264 -preset medium -crf 23 -c:a copy EXPERIMENT/frog-search200_mpdecimate=hi=1:lo=1.mp4
vlc EXPERIMENT/frog-search200_mpdecimate=hi=1:lo=1.mp4

# %%
ffmpeg -i EXPERIMENT/frog-5_param10-search200.mp4 -vf "mpdecimate=hi=0:lo=0" -c:v libx264 -preset medium -crf 23 -c:a copy EXPERIMENT/frog-search200_mpdecimate=hi=0:lo=0.mp4
vlc EXPERIMENT/frog-search200_mpdecimate=hi=0:lo=0.mp4

# %%
ffmpeg -i EXPERIMENT/frog-5_param10-search200.mp4 -vf "mpdecimate=hi=5:lo=1" -c:v libx264 -preset medium -crf 23 -c:a copy EXPERIMENT/frog-search200_mpdecimatehi5_lo1.mp4
vlc EXPERIMENT/frog-search200_mpdecimatehi5_lo1.mp4

# %%
ffmpeg -i EXPERIMENT/frog-5_param10-search200.mp4 -vf "mpdecimate=hi=0:lo=0" -c:v libx264 -preset medium -crf 23 -c:a copy EXPERIMENT/frog-search200_mpdecimatehi0_lo0.mp4
vlc EXPERIMENT/frog-search200_mpdecimatehi0_lo0.mp4

# %%
vlc EXPERIMENT/frog-search200_mpdecimatehi0_lo0.mp4

# %%
#And with the slightly ridiculous value of 2000:
ffmpeg -hide_banner -i tinydir/output25.mp4 -filter:v "setpts=10*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=32'" -y tinydir/search_param10-32.mp4

#The biggest difference is clearly between setting the search_param from 32 to 400. At 2000 there’s only minor differences, though this may change depending on your source input.

# %%
vlc EXPERIMENT/frog-search200_mpdecimatehi5_lo1.mp4

# %%
#And with the slightly ridiculous value of 2000:
ffmpeg -hide_banner -i tinydir/output25.mp4 -filter:v "setpts=10*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=32'" -y tinydir/search_param10-32.mp4

#The biggest difference is clearly between setting the search_param from 32 to 400. At 2000 there’s only minor differences, though this may change depending on your source input.

# %%
setpts=10*PTS to setpts=20*PTS - slow it down

# %%
#And with the slightly ridiculous value of 2000:
ffmpeg -hide_banner -i tinydir/output25.mp4 -filter:v "setpts=20*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=32'" -y tinydir/search_param_20-32.mp4

#The biggest difference is clearly between setting the search_param from 32 to 400. At 2000 there’s only minor differences, though this may change depending on your source input.

# %%
vlc tinydir/search_param_20-32.mp4

# %%
#And with the slightly ridiculous value of 2000:
ffmpeg -hide_banner -i tinydir/output25.mp4 -filter:v "setpts=30*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=400'" -y tinydir/search_param_30-400.mp4

#The biggest difference is clearly between setting the search_param from 32 to 400. At 2000 there’s only minor differences, though this may change depending on your source input.

# %%
setpts=15*PTS   Controls the speed search_param=400
the video is geting longer with the setpts=30*PTS

# %%
vlc EXPERIMENT/frog-search200_mpdecimatehi5_lo1.mp4

# %%
vlc tinydir/search_param_40-400.mp4

# %%
#And with the value of 400:
ffmpeg -hide_banner -i tinydir/output25.mp4 -filter:v "setpts=40*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=400'" -y tinydir/search_param_40-400.mp4

#The biggest difference is clearly between setting the 'search_param from 32 to 400'. At 2000 there’s only minor differences, though this may change depending on your source input.

# %%
vlc tinydir/output25.mp4

# %%
#!/bin/bash

# set input and output file names
input_file="tinydir/output25.mp4"
output_file="60-fast-didir-1-32.mp4"

# set interpolation parameters
fps=60       # frames per second of the output video
scd=fastest     # scene change detection mode (fast, medium, accurate)
me_mode=bidir  # motion estimation mode (bidir, obmc, gm)
vsbmc=1      # use variable block size motion compensation
search_param=32  # search parameter for motion estimation
t=10
# run FFmpeg command to interpolate the video
ffmpeg -i "$input_file" -filter:v "minterpolate='fps=$fps:scd=$scd:me_mode=$me_mode:vsbmc=$vsbmc:search_param=$search_param'" -t $t -y "$output_file"

# %%
vlc 60-fast-didir-1-32.mp4

# %% [markdown]
# # Test Script

# %%
#!/bin/bash

# set input and output file names
input_file="tinydir/output25.mp4"
output_file="tinydir/20-fast-didir-1-32.mp4"

# set interpolation parameters
fps=60       # frames per second of the output video
scd=none     # scene change detection mode (fast, medium, accurate)
me_mode=bidir  # motion estimation mode (bidir, obmc, gm)
vsbmc=1      # use variable block size motion compensation
search_param=32  # search parameter for motion estimation
setpts=60*PTS
# run FFmpeg command to interpolate the video
ffmpeg -i "$input_file" -filter:v "'setpts'=$setpoints,minterpolate='fps=$fps:scd=$scd:me_mode=$me_mode:vsbmc=$vsbmc:search_param=$search_param'" -y "$output_file"

# %%
#And with the value of 4000:
ffmpeg -hide_banner -i tinydir/output25.mp4 -filter:v "setpts=50*PTS,minterpolate='fps=30:scd=fast:search_param=32'" -y tinydir/scd-fast-nonesearch_param_50-1000.mp4

# %%
ffmpeg -i input.mp4 -filter:v "minterpolate='fps=30:scd=fast:search_param=32'" output.mp4

# %%
vlc tinydir/search_param_50-4000.mp4

# %%
This will remove the frames where there was no movement

# %%
ffmpeg -i tinydir/search_param_50-4000.mp4 -vf mpdecimate,setpts=N/FRAME_RATE/TB no-dups-search_param_50-4000.mp4

# %%
vlc no-dups-search_param_50-4000.mp4

# %%
notice consistent change no stopping to show the image

# %%
ffmpeg -hide_banner -framerate 25 -i tinydir/%05d.jpg -c:v libx264 -pix_fmt yuv420p -y output25.mp4

# %%
vlc tinydir/output5.mp4

# %%
ls tinydir

# %%
rename 's/\d+/sprintf("%06d", $&)/e' *.jpg

# %%
FFMPEG -framerate 5 -i %05d.png -c:v libx265 -r 20 -pix_fmt yuv420p -y archived-images.mp4

# %%
input_folder="/home/jack/Downloads/saved_pages/ReV_Animated_Stable_Diffusion_Checkpoint_Civitai_files/square"
ls ${input_folder}

# %%
ffmpeg -i input.mp4 -vf "pad=ih*16/9:ih:(ow-iw)/2:0:black" -c:a copy output.mp4

# %%
# Define input folder and file extension
input_folder="/home/jack/Desktop/HDD500/Downloads/00de3/butterflies/frog/leonardo.ai_files"
file_extension=".jpg"

# Define output file path and name
output_file="/home/jack/Desktop/ffmpegSlideshowBlendfrog.mp4"
filter_complex=""

# Set the video dimensions to 512x910 for a portrait video with a 9:16 aspect ratio
video_dimensions="512x1024"

# Loop through all files in the input folder and add them to the filter complex
for file in "$input_folder"/*"$file_extension"; do
  filter_complex="$filter_complex[$((i+1)):v]trim=duration=$slideshow_duration,fade=t=in:st=0:d=$transition_duration,fade=t=out:st=$((slideshow_duration-transition_duration)):d=$transition_duration,setsar=1:1[v$i];"
  i=$((i+1))
done

# Remove the last semicolon from the filter complex
filter_complex="${filter_complex%;}"

# Add the concat filter to the end of the filter complex
filter_complex="$filter_complex$(for i in $(seq 0 $(($(ls "$input_folder"/*"$file_extension" | wc -l)-1))); do echo "[v$i]"; done | tr -d '\n')concat=n=$(ls "$input_folder"/*"$file_extension" | wc -l):v=1:a=0,setsar=1:2[v]"

# Debug information
echo "Number

# %%
# Define input folder and file extension
input_folder="/home/jack/Desktop/HDD500/Downloads/00de3/butterflies/frog/leonardo.ai_files"
file_extension=".jpg"

# Define output file path and name
output_file="/home/jack/Desktop/ffmpegSlideshowBlendfrog.mp4"
filter_complex=""

# Set the video dimensions to 512x910 for a portrait video with a 9:16 aspect ratio
video_dimensions="512x1024"

# Loop through all files in the input folder and add them to the filter complex
for file in "$input_folder"/*"$file_extension"; do
  filter_complex="$filter_complex[$((i+1)):v]trim=duration=$slideshow_duration,fade=t=in:st=0:d=$transition_duration,fade=t=out:st=$((slideshow_duration-transition_duration)):d=$transition_duration,setsar=1:1[v$i];"
  i=$((i+1))
done

# Remove the last semicolon from the filter complex
filter_complex="${filter_complex%;}"

# Add the concat filter to the end of the filter complex
filter_complex="$filter_complex$(for i in $(seq 0 $(($(ls "$input_folder"/*"$file_extension" | wc -l)-1))); do echo "[v$i]"; done | tr -d '\n')concat=n=$(ls "$input_folder"/*"$file_extension" | wc -l):v=1:a=0,setsar=1:2[v]"

# Run FFmpeg with the defined filter complex and output file
ffmpeg -hide_banner -y -loop 1 -i "${input_folder}/$(ls "$input_folder" | head -n 1)" -filter_complex "$filter_complex" -map "[v]" -s "$video_dimensions" -r 24 -strict -2 "$output_file"

# %%
ls /home/jack/Desktop/HDD500/Downloads/00de3/butterflies/frog/leonardo.ai_files/00001.jpg

# %%
#!/bin/bash

# Define input folder and file extension
input_folder="/home/jack/Desktop/HDD500/Downloads/00de3/butterflies/frog/leonardo.ai_files"
file_extension=".jpg"

# Define output file path and name
output_file="/home/jack/Desktop/ffmpegSlideshowBlendfrog.mp4"

# Define slideshow duration and transition duration
slideshow_duration="6"
transition_duration="1"

# Create the FFmpeg filter complex
filter_complex=""

# Loop through all files in the input folder and add them to the filter complex
for file in "$input_folder"/*"$file_extension"; do
  filter_complex="$filter_complex[0:v]trim=duration=$slideshow_duration,fade=t=in:st=0:d=$transition_duration,fade=t=out:st=$((slideshow_duration-transition_duration)):d=$transition_duration,setsar=1:1[v$(basename "$file" "$file_extension")];"
done

# Remove the last semicolon from the filter complex
filter_complex="${filter_complex%;}"

# Add the concat filter to the end of the filter complex
filter_complex="$filter_complex$(for i in $(seq 0 $(($(ls "$input_folder"/*"$file_extension" | wc -l)-1))); do echo "[v$i]"; done | tr -d '\n')concat=n=$(ls "$input_folder"/*"$file_extension" | wc -l):v=1:a=0,setsar=1:1[v]"

# Run FFmpeg with the defined filter complex and output file
ffmpeg -hide_banner -y -loop 1 -i "${input_folder}/$(ls "$input_folder" | head -n 1)" -filter_complex "$filter_complex" -map "[v]" -s 512x1024 -r 24 -strict -2 "$output_file"

# %%
ffmpeg -y /home/jack/Downloads/saved_pages/ReV_Animated_Stable_Diffusion_Checkpoint_Civitai_files/square/00419up.jpg -loop 1 -i /home/jack/Downloads/saved_pages/ReV_Animated_Stable_Diffusion_Checkpoint_Civitai_files/square/00415up.jpg -loop 1 -i /home/jack/Downloads/saved_pages/ReV_Animated_Stable_Diffusion_Checkpoint_Civitai_files/square/00414up.jpg -loop 1 -i /home/jack/Downloads/saved_pages/ReV_Animated_Stable_Diffusion_Checkpoint_Civitai_files/square/00413up.jpg -loop 1 -i /home/jack/Downloads/saved_pages/ReV_Animated_Stable_Diffusion_Checkpoint_Civitai_files/square/00406up.jpg -filter_complex "[0:v]trim=duration=6,fade=t=in:st=0:d=1,fade=t=out:st=5:d=1,setsar=1:1[v0];[1:v]trim=duration=6,fade=t=in:st=0:d=1,fade=t=out:st=5:d=1,setsar=1:1[v1]; [2:v]trim=duration=6,fade=t=in:st=0:d=1,fade=t=out:st=5:d=1,setsar=1:1[v2]; [3:v]trim=duration=6,fade=t=in:st=0:d=1,fade=t=out:st=5:d=1,setsar=1:1[v3]; [4:v]trim=duration=6,fade=t=in:st=0:d=1,fade=t=out:st=5:d=1,setsar=1:1[v4]; [5:v]trim=duration=6,fade=t=in:st=0:d=1,fade=t=out:st=5:d=1,setsar=1:1[v5]; [6:v]trim=duration=6,fade=t=in:st=0:d=1,fade=t=out:st=5:d=1,setsar=1:1[v6]; [v0][v1][v2][v3][v4][v5][v6]concat=n=7:v=1:a=0,setsar=1:1[v]" -map "[v]" -s 640x640 -strict -2 -r 24 /home/jack/Desktop/ffmpegSlideshowBlend02.mp4;

# %%
locate hot.mp4

# %%
cp /mnt/HDD500/collections/newdownloads/mine-new/Title.jpg .

# %%
vlc complete/start.mp4

# %%
pwd

# %%
ls -rant complete

# %%
ffmpeg -y -f image2 -pattern_type glob -i complete/*.jpg -c:v libx265 -r 20 -pix_fmt yuv420p complete/start.mp4

# %%
ffmpeg -y -f image2 -pattern_type glob -i 'complete/*.jpg' -c:v libx265 -r 20 -pix_fmt yuv420p start.mp4

# %%
!ls complete

# %%
ffmpeg -framerate 3 -pattern_type glob -i "/home/jack/Downloads/IMAGES/*.jpg" -c:v libx264 -preset ultrafast -qp 0 -r 30 -pix_fmt yuv420p -y IMAGES/video.mp4

# %%
SE complete/splatter.mp4

# %%
ffmpeg -framerate 30 -pattern_type glob -i "complete/*.jpg" -c:v libx264 -preset ultrafast -qp 0 -r 30 -pix_fmt yuv420p -y complete/frames4.mp4

# %%
ffmpeg -i lnm_faces_original.mp4 -filter:v "setpts=40*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=400'" -y output.mp4

# %%
#WORKS GREAT
import os
import random
from moviepy.editor import VideoFileClip, ImageClip, CompositeVideoClip, concatenate_videoclips

# Set the duration of the cross-fade transition in seconds
transition_duration = 1

# Set the duration of the title image in seconds
title_duration = 2

# Load the title image as an ImageClip object
title_image = ImageClip('Title.jpg', duration=title_duration)

# Get a list of all the .mp4 files in the current directory
mp4_files = [f for f in os.listdir('/mnt/HDD500/collections/newdownloads/mine-new') if os.path.isfile(f) and f.endswith('hot.mp4')]

# Choose 10 random files from the list
selected_files = random.sample(mp4_files, 6)

# Load each selected file as a VideoFileClip object
clips = [VideoFileClip(file) for file in selected_files]

# Add cross-fade transitions between the clips
transitions = [None] * (len(clips) - 1)
for i in range(len(transitions)):
    transition_out = clips[i].crossfadeout(transition_duration)
    transition_in = clips[i+1].crossfadein(transition_duration)
    transition = CompositeVideoClip([transition_out, transition_in])
    transitions[i] = transition

# Calculate the transition for the last two clips separately
last_transition_out = clips[-2].crossfadeout(transition_duration)
last_transition_in = clips[-1].crossfadein(transition_duration)
last_transition = CompositeVideoClip([last_transition_out, last_transition_in])

# Concatenate the title image, the clips, and the transitions into one video
title_video = concatenate_videoclips([title_image])
final_video = concatenate_videoclips([title_video, clips[0]])
for i in range(len(transitions)):
    final_video = concatenate_videoclips([final_video, transitions[i], clips[i+1]])
final_video = concatenate_videoclips([final_video, last_transition, clips[-1]])

# Write the final video to a file
final_video.write_videofile('test-output-HOT.mp4')
blend mp4 together

# %%
ffmpeg -i lnm_faces_original.mp4 -filter:v "setpts=40*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=400'" -y output.mp4

# %%
https://www.hellocatfood.com/misusing-ffmpegs-motion-interpolation-options/
setpts
The FFmpeg wiki has a good explanation of what setpts does:
    To double the speed of the video, you can use:
    ffmpeg -i input.mkv -filter:v "setpts=0.5*PTS" output.mkv
    The filter works by changing the presentation timestamp (PTS) of each video frame. For example, if there are two successive frames shown at timestamps 1 and 2, and you want to speed up the video, those timestamps need to become 0.5 and 1, respectively. Thus, we have to multiply them by 0.5.
So, by using setpts=40*PTS I’m essentially slowing the video down by a factor of 40. For this video I took a guess at much I’d need to multiply the video of the faces to make it match the length of the video. If I wanted to be exact I’d need to use some maths and divide the frame count of the video (5268), divide it by the frame count of the face video (47) and use the output (112.085106383) as the PTS multiplier.
scd

scd is probably the most important part of this code. It attempts to detect if there’s any scene changes and then not perform any motion interpolation on those frames. In this scenario, however, I want to interpolate between every frame, regardless of whether they appear to be part of the same “scene”. If you leave scd at the default of fdiff and scd_threshold at 5.0 ffmpeg tries to decide if there’s enough difference between frames. Here’s what that would’ve looked like:

# %%
ffmpeg -i search_param_400.mp4 -filter:v "setpts=40*PTS,minterpolate='fps=25:me_mode=bidir:vsbmc=1:search_param=400'" -y lnm_faces_search_param_scd.mp4

# %%
ffmpeg -i faces.mp4 -filter:v "setpts=40*PTS,minterpolate='fps=25:me_mode=bidir:vsbmc=1:search_param=400'" -y lnm_faces_scd.mp4
(without setting scd the defaults are assumed)

Not ideal, so I disabled it by setting it to none.
search_param

This one I don’t quite understand but I understand how it affects the video. If I were to leave the setting with the default value of 32 then you can see that when it interpolates there isn’t much movement:

# %%
ffmpeg -i faces.mp4 -filter:v "setpts=40*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=32'" -y search_param_32.mp4

With the value of 400 which I used:

# %%
pwd

# %%
ffmpeg -i start-01.mp4 -filter:v "setpts=40*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=400'" -y search_param_400.mp4

# %%
#And with the slightly ridiculous value of 2000:
ffmpeg -i faces.mp4 -filter:v "setpts=40*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=2000'" -y search_param_2000.mp4

#The biggest difference is clearly between setting the search_param from 32 to 400. At 2000 there’s only minor differences, though this may change depending on your source input.

# %%
/home/jack/Downloads/lexica/00021lex.jpg

# %%
#!/bin/bash

# Define input folder and file extension
input_folder="/home/jack/Downloads/lexica/"
file_extension=".jpg"

# Define output file path and name
output_file="/home/jack/Desktop/ffmpegSlideshowBlend2.mp4"

# Define slideshow duration and transition duration
slideshow_duration="6"
transition_duration="1"

# Create the FFmpeg filter complex
filter_complex=""

# Loop through all files in the input folder and add them to the filter complex
for file in "$input_folder"/*"$file_extension"; do
  filter_complex="$filter_complex[0:v]trim=duration=$slideshow_duration,fade=t=in:st=0:d=$transition_duration,fade=t=out:st=$((slideshow_duration-transition_duration)):d=$transition_duration,setsar=1:1[v$(basename "$file" "$file_extension")];"
done

# Remove the last semicolon from the filter complex
filter_complex="${filter_complex%;}"

# Add the concat filter to the end of the filter complex
filter_complex="$filter_complex$(for i in $(seq 0 $(($(ls "$input_folder"/*"$file_extension" | wc -l)-1))); do echo "[v$i]"; done | tr -d '\n')concat=n=$(ls "$input_folder"/*"$file_extension" | wc -l):v=1:a=0,setsar=1:1[v]"

# Run FFmpeg with the defined filter complex and output file
ffmpeg -y -loop 1 -i "${input_folder}/$(ls "$input_folder" | head -n 1)" -filter_complex "$filter_complex" -map "[v]" -s 640x640 -r 24 -strict -2 "$output_file"
ERROR:
AR 1:1 DAR 2:3], 25 fps, 25 tbr, 25 tbn, 25 tbc
[AVFilterGraph @ 0x55cb87450840] No output pad can be associated to link label 'v0'.
Error initializing complex filters.
Invalid argument

# %%
ls /home/jack/Downloads/saved_pages/ReV_Animated_Stable_Diffusion_Checkpoint_Civitai_files/square

# %%
#!/bin/bash

# Define input folder and file extension
input_folder="/home/jack/Downloads/saved_pages/ReV_Animated_Stable_Diffusion_Checkpoint_Civitai_files/square"
file_extension=".jpg"

# Define output file path and name
output_file="/home/jack/Desktop/ffmpegSlideshowBlend.mp4"

# Define slideshow duration and transition duration
slideshow_duration="6"
transition_duration="1"

# Create the FFmpeg filter complex
filter_complex=""

# Loop through all files in the input folder and add them to the filter complex
for file in "$input_folder"/*"$file_extension"; do
  filter_complex="$filter_complex[0:v]trim=duration=$slideshow_duration,fade=t=in:st=0:d=$transition_duration,fade=t=out:st=$((slideshow_duration-transition_duration)):d=$transition_duration,setsar=1:1[v$(basename "$file" "$file_extension")];"
done

# %%
#!/bin/bash

# Define input folder and file extension
input_folder="/home/jack/Downloads/saved_pages/ReV_Animated_Stable_Diffusion_Checkpoint_Civitai_files/square"
file_extension=".jpg"

# Define output file path and name
output_file="/home/jack/Desktop/ffmpegSlideshowBlend.mp4"

# Define slideshow duration and transition duration
slideshow_duration="6"
transition_duration="1"

# Create the FFmpeg filter complex
filter_complex=""

# Loop through all files in the input folder and add them to the filter complex
for file in "$input_folder"/*"$file_extension"; do
  filter_complex="$filter_complex[0:v]trim=duration=$slideshow_duration,fade=t=in:st=0:d=$transition_duration,fade=t=out:st=$((slideshow_duration-transition_duration)):d=$transition_duration,setsar=1:1[v$(basename "$file" "$file_extension")];"
done

# Remove the last semicolon from the filter complex
filter_complex="${filter_complex%;}"

# Add the concat filter to the end of the filter complex
filter_complex="$filter_complex$(for i in $(seq 0 $(($(ls "$input_folder"/*"$file_extension" | wc -l)-1))); do echo "[v$i]"; done | tr -d '\n')concat=n=$(ls "$input_folder"/*"$file_extension" | wc -l):v=1:a=0,setsar=1:1[v]"

# Run FFmpeg with the defined filter complex and output file
ffmpeg -y -loop 1 -i "${input_folder}/$(ls "$input_folder" | head -n 1)" -filter_complex "$filter_complex" -map "[v]" -s 640x640 -r 24 -strict -2 "$output_file"

# %%
ffmpeg -i '/mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/IMAGES/%05d.jpg' -c:v libx265 -r 20 -pix_fmt yuv420p -y /mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/IMAGES/start.mp4

# %%
ls /mnt/HDD500/0WORKSHOP-with-NOTEBOOKS/IMAGES/

# %%
SpecialEffect

# %%
ffmpeg -hide_banner -f alsa -i hw:0,0 -acodec libmp3lame -t 30 -y testing.mp3
ffmpeg -hide_banner -i testing.mp3 -y testing.wav
play testing.wav
sox testing.wav -c 1 temp_file.wav
sox temp_file.wav -n noiseprof noise_profile_file
sox temp_file.wav output_file.wav noisered noise_profile_file 0.21
play output_file.wav

# %%
sox testing.wav noise.wav trim 0 5
sox testing.wav output.wav noisered noise.wav 0.21
sox FAIL noisered: noisered: channel mismatch: 2 in input, 0 in profile.

# %%
#!/bin/bash
audacity -b testing.mp3 -o clntesting.mp3 --effect NoiseReduction --plot 0 --print-lengths 0 --print-stats 0 --shape 1 --pad 1 --verbose --start-time 0 --end-time 25 --no-color --no-progress --no-log --nyquist-rate 44100 --plugin-args "rn:noise_reduction=.21,rn:noise_reduction_type=1,rn:noise_power=.21,rn:fft_size=512,rn:window_size=0.05,rn:noise_algorithm=1,rn:sensitivity=0.5,rn:frequency_smoothing=0.05,rn:attack_time=0.05,rn:decay_time=0.2,rn:passband=0,rn:noise_fading=1,rn:noise_fade_band=0.01"

# %%
play clntesting.mp3

# %%
Sox (short for Sound eXchange) is a powerful and versatile command-line tool used for processing audio files. It can be used to convert audio file formats, adjust audio parameters like volume and pitch, apply various audio effects, and perform many other audio processing tasks.

Here are some of the basic commands and options for using SoX:

    Converting audio file formats:

    To convert an audio file from one format to another, use the following command:

    sox input_file.wav output_file.mp3

    This will convert the WAV file to an MP3 file. You can replace the file extensions with any other supported formats.

    Adjusting audio parameters:

    You can adjust various audio parameters using SoX. For example, to increase the volume of an audio file, use the following command:

    sox input_file.wav output_file.wav vol 3dB

    This will increase the volume of the WAV file by 3 decibels. You can also decrease the volume by using a negative value.

    You can also adjust the pitch of an audio file using the pitch effect. For example:

    sox input_file.wav output_file.wav pitch 500

    This will increase the pitch of the WAV file by 500 Hz.

    Applying audio effects:

    SoX has a wide range of built-in audio effects that you can use to modify the sound of an audio file. For example, to add a reverb effect to an audio file, use the following command:

    sox input_file.wav output_file.wav reverb 50 50 100 50 0.2

    This will add a reverb effect to the WAV file with a decay time of 50%, a pre-delay of 50ms, a wet gain of 100%, and a stereo width of 50%. The last parameter specifies the mix of dry and wet sound.

    To remove noise from an audio file, you can use the noisered effect. First, you need to create a noise profile file by running the following command:

    sox input_file.wav -n noiseprof noise_profile_file

    This will create a noise profile file from the input file. Then, you can use the following command to remove the noise:

    sox input_file.wav output_file.wav noisered noise_profile_file 0.21

    This will remove the noise from the WAV file using the noise profile file with a sensitivity of 0.21.

These are just some of the basic commands and options for using SoX. SoX has many more features and options that you can explore by referring to its documentation.
Free Research Preview. ChatGPT may produce inaccurate information about people, places, or facts. ChatGPT Mar 23 Version

# %%
bash

#!/bin/bash

# Create the destination directory if it doesn't exist
mkdir -p 512x1024

# Iterate over all the .jpg files in the current directory
for file in *.jpg; do
    # Check the dimensions of each image using ImageMagick's identify command
    dimensions=$(identify -format "%wx%h" "$file")

    # Check if the dimensions match 512x1024
    if [ "$dimensions" = "512x1024" ]; then
        # Move the image to the 512x1024 directory
        mv "$file" 512x1024/
    fi
done

# %%
#!/bin/bash

# Define input folder and file extension
input_folder="/home/jack/Desktop/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/shaman/leonardo.ai_files"
file_extension=".jpg"

# Define output file path and name
output_file="/home/jack/Desktop/ShamanSlideshowBlend.mp4"

# Define slideshow duration and transition duration
slideshow_duration="6"
transition_duration="1"

# Create the FFmpeg filter complex
filter_complex=""

# Loop through all files in the input folder and add them to the filter complex
for file in "$input_folder"/*"$file_extension"; do
  filter_complex="$filter_complex[0:v]trim=duration=$slideshow_duration,fade=t=in:st=0:d=$transition_duration,fade=t=out:st=$((slideshow_duration-transition_duration)):d=$transition_duration,setsar=1:1[v$(basename "$file" "$file_extension")];"
done

# Remove the last semicolon from the filter complex
filter_complex="${filter_complex%;}"

# Add the concat filter to the end of the filter complex
filter_complex="$filter_complex$(for i in $(seq 0 $(($(ls "$input_folder"/*"$file_extension" | wc -l)-1))); do echo "[v$i]"; done | tr -d '\n')concat=n=$(ls "$input_folder"/*"$file_extension" | wc -l):v=1:a=0,setsar=1:1[v]"

# Run FFmpeg with the defined filter complex and output file
ffmpeg -y -loop 1 -i "${input_folder}/$(ls "$input_folder" | head -n 1)" -filter_complex "$filter_complex" -map "[v]" -s 640x640 -r 24 -strict -2 "$output_file"

# %%
VIDEO=IMAGES/Leonardo_Painting.mp4

# %%
#And with the slightly ridiculous value of 2000:
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=10*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -y IMAGES/Leonardo_Painting_se10.mp4

#The biggest difference is clearly between setting the search_param from 32 to 400. At 2000 there’s only minor differences, though this may change depending on your source input.

# %%
ffmpeg -hide_banner -framerate 5 -i /home/jack/Desktop/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/shaman/%05d.jpg -c:v libx264 -r 30 -pix_fmt yuv420p EXPERIMENT/leonardo_Sham-5.mp4
vlc EXPERIMENT/leonardo_Sham-5.mp4

# %%
VIDEO=EXPERIMENT/leonardo_Sham-5.mp4
OUTPUT=EXPERIMENT/SE.mp4

# %%
ffmpeg -hide_banner -i ${VIDEO} -filter:v "minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -y ${OUTPUT}
vlc EXPERIMENT/SE.mp4

# %%
vlc EXPERIMENT/SE.mp4

# %%
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=4*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -y EXPERIMENT/SE4.mp4
vlc EXPERIMENT/SE4.mp4

# %%
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=4*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -y EXPERIMENT/SE4.mp4
vlc EXPERIMENT/SE4.mp4

# %%
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=10*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -y EXPERIMENT/SE10.mp4
vlc EXPERIMENT/SE10.mp4

# %%
ffmpeg -i EXPERIMENT/titled.mp4 -i ${MUSIC} -filter_complex "[0:v] [1:a] concat=n=1:v=1:a=1 [v] [a]" -map "[v]" -map "[a]" -c:a aac -shortest -t 59 -y EXPERIMENT/titled_with_music6.mp4
vlc EXPERIMENT/titled_with_music6.mp4

# %%
ffprobe -i EXPERIMENT/titled.mp4 -show_streams

# %%
ffmpeg -i EXPERIMENT/titled.mp4 -i ${MUSIC} -filter_complex "[1:a]afade=t=in:ss=0:d=3,afade=t=out:st=54:d=3,atrim=0:54[a];[0:v]scale=768:512,setsar=1[v];[v][a]concat=n=2:v=1:a=1[v][a]" -map "[v]" -map "[a]" -c:v libx264 -c:a aac -shortest -y EXPERIMENT/titled_with_sound2.mp4
vlc EXPERIMENT/titled_with_sound2.mp4

# %%
ffmpeg -i EXPERIMENT/titled.mp4 -i ${MUSIC} -filter_complex "[0:a]atrim=start=${START_TIME}:end=${END_TIME},asetpts=PTS-STARTPTS,afade=t=in:ss=0:d=3,afade=t=out:st=${END_FADE_TIME}:d=3[a];[0:a][a]amix=duration=shortest" -c:a aac -shortest -y EXPERIMENT/titled_with_sound2.mp4
vlc EXPERIMENT/titled_with_sound2.mp4

# %%
ffmpeg -i EXPERIMENT/titled.mp4 -i ${MUSIC} -filter_complex "[0:v] [1:a] concat=n=1:v=1:a=1 [v] [a]" -map "[v]" -map "[a]" -c:a aac -shortest -t 59 -y EXPERIMENT/titled_with_music6.mp4
vlc EXPERIMENT/titled_with_music6.mp4

# %%
START_TIME="00:10:00"
END_TIME="00:58:00"
FADE_DURATION=3
MUSIC="/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3"

START_TIME_SECONDS=$(date -u -d "${START_TIME}" +"%s")
END_TIME_SECONDS=$(date -u -d "${END_TIME}" +"%s")
DURATION_SECONDS=$((END_TIME_SECONDS - START_TIME_SECONDS))
END_FADE_SECONDS=$((END_TIME_SECONDS - FADE_DURATION))

ffmpeg -i "${MUSIC}" -ss "${START_TIME}" -filter_complex "[0:a]atrim=start=0:end=${DURATION_SECONDS},afade=t=in:ss=0:d=${FADE_DURATION},afade=t=out:st=${END_FADE_SECONDS}:d=${FADE_DURATION}[a];[0:a][a]amix=duration=shortest" -c:a aac -y trimmed_music.mp3


vlc trimmed_music.mp3

# %%
MUSIC="/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3"
vlc ${MUSIC}

# %%
START_TIME="00:10:00"
END_TIME="00:58:00"
MUSIC="/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3"
ffmpeg -i "${MUSIC}" -ss "${START_TIME}" -to "${END_TIME}" -c:a copy -y trimmed_music.mp3

vlc trimmed_music.mp3

# %%
START_TIME="00:10:00"
END_TIME="00:58:00"
MUSIC="/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3"
ffmpeg -i "${MUSIC}" -ss "${START_TIME}" -to "${END_TIME}" -c:a aac -af "afade=t=in:ss=0:d=3,afade=t=out:st=${END_TIME}:d=3" -y trimmed_music.mp3
vlc trimmed_music.mp3

# %%
START_TIME="00:10:00"
END_TIME="00:58:00"
MUSIC=/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3
ffmpeg -i "${MUSIC}" -ss "${START_TIME}" -to "${END_TIME}" -c:a aac -af "afade=t=in:ss=0:d=3,afade=t=out:st=${END_TIME}-3:d=3" -y trimmed_music.mp3
vlc trimmed_music.mp3
    Metadata:
      encoder         : Lavc58.54
Stream mapping:
  Stream #0:0 -> #0:0 (mp3 (mp3float) -> aac (native))
Press [q] to stop, [?] for help
[afade @ 0x55c2a3dd6ac0] Value 58.000000 for parameter 'type' out of range [0 - 1]
[afade @ 0x55c2a3dd6ac0] Value -3.000000 for parameter 'start_sample' out of range [0 - 9.22337e+18]
[afade @ 0x55c2a3dd6ac0] Value 58.000000 for parameter 'type' out of range [0 - 1]
[afade @ 0x55c2a3dd6ac0] Error setting option type to value 58.
[Parsed_afade_1 @ 0x55c2a3dd69c0] Error applying options to the filter.
[AVFilterGraph @ 0x55c2a3dc4300] Error initializing filter 'afade' with args 't=out:st=00:58:00-3:d=3'
Error reinitializing filters!
Failed to inject frame into filter network: Numerical result out of range
Error while processing the decoded data for stream #0:0
Conversion failed!
VLC media player 3.0.11.1 Vetinari (revision 3.0.11.1-0-g52483f3ca2)
[00000000025c20c0] main libvlc: Running vlc with the default interface. Use 'cvlc' to use vlc without interface.
[00007fb498001a10] cache_read stream error: cannot pre fill buffer
[00007fb498001190] mjpeg demux error: cannot peek
QObject::~QObject: Timers cannot be stopped from another thread

# %%
START_TIME=$(shuf -i 0-3600 -n 1)  # Random start time within the first hour

# %%
START_TIME="00:10:00"
END_TIME="00:58:00"
MUSIC=/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3
ffmpeg -i ${MUSIC} -ss ${START_TIME} -t ${END_TIME} -c:a aac -af "afade=t=in:ss=0:d=3,afade=t=out:st=${END_FADE}-3:d=3" -y trimmed_music.mp3
vlc trimmed_music.mp3

# %%
START_TIME="00:10:00"
END_TIME="00:58:00"
MUSIC="/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3"
ffmpeg -i "${MUSIC}" -ss "${START_TIME}" -to "${END_TIME}" -c:a copy -y trimmed_music.mp3
vlc trimmed_music.mp3

# %%
vlc EXPERIMENT/titled.mp4

# %%
vlc trimmed_music.mp3

# %%
# Get audio duration and round it to an integer
duration=$(ffprobe -i trimmed_music.mp3 -show_entries format=duration -v quiet -of csv="p=0")
duration_rounded=$(echo "($duration+0.5)/1" | bc)

# Trim audio and merge
ffmpeg -i EXPERIMENT/titled.mp4 -i trimmed_music.mp3 -filter_complex "[0:a]atrim=0:${duration_rounded}[a1];[1:a]atrim=0:${duration_rounded}[a2];[a1][a2]amerge=inputs=2[a]" -map 0:v -map "[a]" -c:v copy -c:a aac -shortest -y EXPERIMENT/titled_with_sound3.mp4

# %%
random_number=$(( RANDOM % 1900 + 100 ))

# %%
#WORKS
random_number=$(( RANDOM % 1900 + 100 ))
ffmpeg -ss 0 -i EXPERIMENT/titled.mp4 -ss ${random_number} -i trimmed_music.mp3 -map 0:v -map 1:a -c:v copy -c:a aac -shortest -y EXPERIMENT/titled_with_sound3.mp4
vlc EXPERIMENT/titled_with_sound3.mp4

# %%
# Get audio duration
duration=$(ffprobe -i trimmed_music.mp3 -show_entries format=duration -v quiet -of csv="p=0")
echo ${duration}
# Trim audio and merge
ffmpeg -i EXPERIMENT/titled.mp4 -i trimmed_music.mp3 -filter_complex "[0:a]atrim=0:${duration}[a1];[1:a]atrim=0:${duration}[a2];[a1][a2]amerge=inputs=2[a]" -map 0:v -map "[a]" -c:v copy -c:a aac -shortest -y EXPERIMENT/titled_with_sound3.mp4
>>> 2880.000000
Duration: 00:48:00.00, start: 0.011995, bitrate: 128 kb/s
    Stream #1:0: Audio: mp3, 44100 Hz, stereo, fltp, 128 kb/s
    Metadata:
      encoder         : Lavc58.54
Stream specifier ':a' in filtergraph description [0:a]atrim=0:2880.000000[a1];[1:a]atrim=0:2880.000000[a2];[a1][a2]amerge=inputs=2[a] matches no streams.

# %%
ffmpeg -i EXPERIMENT/titled.mp4 -i trimmed_music.mp3 -filter_complex "[0:a]atrim=0:59[a1];[1:a]atrim=0:59[a2];[a1][a2]amerge=inputs=2[a]" -map 0:v -map "[a]" -c:v copy -c:a aac -shortest -y EXPERIMENT/titled_with_sound3.mp4
vlc EXPERIMENT/titled_with_sound3.mp4

# %%
ffmpeg -i EXPERIMENT/titled.mp4 -i trimmed_music.mp3 -filter_complex "[0:a][1:a]amix=duration=shortest" -c:a aac -shortest -y EXPERIMENT/titled_with_sound3.mp4

# %%
ffmpeg -i EXPERIMENT/titled.mp4 -i trimmed_music.mp3 -filter_complex "[0:a][1:a]amix=duration=shortest" -c:a aac -shortest -y EXPERIMENT/titled_with_sound3.mp4
vlc EXPERIMENT/titled_with_sound3.mp4

# %%
MUSIC=/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3
ffmpeg -i ${MUSIC} -ss ${START_TIME} -t ${END_TIME} -c:a aac -af "afade=t=in:ss=0:d=3,afade=t=out:st=${END_FADE_TIME}:d=3" trimmed_music.mp3
ffmpeg -i EXPERIMENT/titled.mp4 -i trimmed_music.mp3 -filter_complex "[0:a][1:a]amix=duration=shortest" -c:v copy -c:a aac -shortest -y EXPERIMENT/titled_with_sound3.mp4

# %%
random_number=$(( RANDOM % 1900 + 100 ))
ffmpeg -ss 0 -i EXPERIMENT/titled.mp4 -ss ${random_number} -i trimmed_music.mp3 -map 0:v -map 1:a -c:v copy -c:a aac -shortest -y EXPERIMENT/titled_with_sound3.mp4
vlc EXPERIMENT/titled_with_sound3.mp4

# %%
MUSIC=/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3
ffmpeg -i EXPERIMENT/titled.mp4 -i ${MUSIC} -filter_complex "[1:a]atrim=start=1:end=59,asetpts=PTS-STARTPTS,afade=t=in:ss=0:d=3,afade=t=out:st=57:d=3[a];[0:a][a]amix=duration=shortest" -c:v copy -c:a aac -shortest -t 59 -y EXPERIMENT/titled_with_sound3.mp4

# %%
MUSIC=/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3
ffmpeg -i EXPERIMENT/titled.mp4 -i ${MUSIC} -filter_complex "[1:a]atrim=start=1:end=59,asetpts=PTS-STARTPTS,afade=t=in:ss=0:d=3,afade=t=out:st=57:d=3[a];[0:a][a]amix=duration=shortest" -c:a aac -shortest -t 59 -y EXPERIMENT/titled_with_sound3.mp4
vlc EXPERIMENT/titled_with_sound3.mp4

# %%
VIDEO=EXPERIMENT/Mixed_Images-5.mp4
OUTPUT=EXPERIMENT/Set-5.mp4
#DIR=/mnt/HDD500/collections/newdownloads/512x512/
DIR=/mnt/HDD500/collections/newdownloads/Discover_and_Generate_AI_Art_OpenArt_files/
FINAL=EXPERIMENT/AI_Art_OpenArt.mp4
MUSIC=/mnt/HDD500/collections/Music/Music-Copyright_Free_Music.mp3

# %%
ffmpeg -hide_banner -framerate 5 -i ${DIR}%05d.jpg -c:v libx264 -r 30 -pix_fmt yuv420p -y ${VIDEO}
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=5*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -t 58 -y ${FINAL}
TITLEimage=${DIR}00003.jpg
ffmpeg -i ${TITLEimage} -vf "drawtext=text='MIXED AI IMAGES':fontfile=/home/jack/fonts/freesansbold.ttf:fontsize=50:fontcolor=white:x=(w-text_w)/2:y=(h-text_h)/2" -y result_image_with_text.jpg
ffmpeg -loop 1 -i result_image_with_text.jpg -vf "fade=t=in:st=0:d=1:alpha=1, fade=t=out:st=3:d=1:alpha=1" -c:v libx264 -t 4 -y result_image_with_text.mp4
ffmpeg -i result_image_with_text.mp4 -i ${FINAL} -filter_complex "[0:v] [1:v] concat=n=2:v=1:a=0 [v]" -map "[v]" -t 59 -y EXPERIMENT/titled.mp4
random_number=$(( RANDOM % 1900 + 100 ))
ffmpeg -ss 0 -i EXPERIMENT/titled.mp4 -ss ${random_number} -i ${MUSIC} -map 0:v -map 1:a -c:v copy -c:a aac -shortest -y EXPERIMENT/titled_with_sound6.mp4
vlc EXPERIMENT/titled_with_sound6.mp4

# %%
ffmpeg -hide_banner -framerate 5 -i ${DIR}%04d.jpg -c:v libx264 -r 30 -pix_fmt yuv420p ${VIDEO}
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=5*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -t 58 -y ${FINAL}
vlc ${FINAL}

# %%
ffmpeg -hide_banner -i ${VIDEO} -filter:v "setpts=5*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -t 58 -y ${FINAL}
vlc ${FINAL}

# %%
ffmpeg -i video.mp4 -vf "pad=768:512:(ow-iw)/2:0:color=darkred" -c:a copy long.mp4

# %%
# PERFECT
ffmpeg -i EXPERIMENT/SE10.mp4 -vf "mpdecimate=hi=1:lo=1:frac=1:max=0" -c:a copy -t 59 -y EXPERIMENT/dup-1_max10.mp4
vlc EXPERIMENT/dup-1_max10.mp4

# %%
!locate *bold.ttf |grep home/jack

# %%
ffmpeg -i result_image_with_text.mp4 -i ${FINAL} -filter_complex "[0:v] [1:v] concat=n=2:v=1:a=1 [v] [0:a] [1:a] concat=n=2:v=0:a=1 [a]" -map "[v]" -map "[a]" titled.mp4
ffmpeg -i result_image_with_text.mp4 -i ${FINAL} -filter_complex "[0:v] [1:v] concat=n=2:v=1:a=0 [v]" -map "[v]" titled.mp4

# %%
TITLEimage=/mnt/HDD500/collections/newdownloads/512x512/0003.jpg
ffmpeg -i ${TITLEimage} -vf "drawtext=text='CYBORGE HEADS':fontfile=/home/jack/fonts/freesansbold.ttf:fontsize=60:fontcolor=white:x=(w-text_w)/2:y=(h-text_h)/2" -y result_image_with_text.jpg
ffmpeg -loop 1 -i result_image_with_text.jpg -vf "fade=t=in:st=0:d=1:alpha=1, fade=t=out:st=3:d=1:alpha=1" -c:v libx264 -t 4 -y result_image_with_text.mp4
ffmpeg -i result_image_with_text.mp4 -i ${FINAL} -filter_complex "[0:v] [1:v] concat=n=2:v=1:a=0 [v]" -map "[v]" -t 59 -y EXPERIMENT/titled.mp4
vlc EXPERIMENT/titled.mp4

# %%
TITLEimage=/mnt/HDD500/collections/newdownloads/512x512/0003.jpg
ffmpeg -i ${TITLEimage} -vf "drawtext=text='My Video':fontfile=/path/to/font.ttf:fontsize=24:fontcolor=white:x=(w-text_w)/2:y=(h-text_h)/2" result_image_with_text.jpg
ffmpeg -loop 1 -i result_image_with_text.jpg -vf "fade=t=in:st=0:d=1:alpha=1, fade=t=out:st=2:d=1:alpha=1" -c:v libx264 -t 3 result_image_with_text.mp4



    Values for hi and lo are for 8x8 pixel blocks and represent actual pixel value differences, so a threshold of 64 corresponds to 1 unit of difference for each pixel, or the same spread out differently over the block.

    A frame is a candidate for dropping if no 8x8 blocks differ by more than a threshold of hi, and if no more than frac blocks (1 meaning the whole image) differ by more than a threshold of lo.

    Default value for hi is 64 * 12, default value for lo is 64 * 5, and default value for frac is 0.33.

ffmpeg -i input.mkv -vf mpdecimate=hi=1:lo=1:frac=1:max=0 output.mkv

Should only drop an image if the whole image has no more than 1 pixel value difference to the previous.

My test with a static image rendered into a 5sec h264 video show that in reality 3 frames out of 125 get dropped. This is possibly due to compression artifacts.

When adjusting the high and low value to 200

ffmpeg -i input.mkv -vf mpdecimate=hi=200:lo=200:frac=1:max=0 output.mkv

then 21 frames are kept.

# %%
ffmpeg -i input.mp4 -vf "pad=768:512:(ow-iw)/2:0:color=0x006400, overlay=(main_w-overlay_w)/2:(main_h-overlay_h)/2" -c:a copy output.mp4

# %%
#Works and looks good 
ffmpeg -i EXPERIMENT/dup-1_max10.mp4 -filter_complex "[0:v]pad=768:512:(ow-iw)/2:0:color=0x000000[padded]; [padded][0:v]overlay=(main_w-overlay_w)/2:(main_h-overlay_h)/2" -c:a copy -y EXPERIMENT/YouTube_dup-1_max10.mp4

# %%
ffmpeg -i EXPERIMENT/YouTube_dup-1_max10.mp4 -loop 1 -i /home/jack/Desktop/HDD500/0WORKSHOP-with-NOTEBOOKS/saved_pages/shaman/AI_SHAMAN.jpg -filter_complex "[1:v]fade=out:st=0:d=2[fade_image]; [0:v][fade_image]overlay=(main_w-overlay_w)/2:(main_h-overlay_h)/2:enable='between(t,0,3)'" -c:a copy -t 58 -y EXPERIMENT/YouTube_dup-1_max10-intro.mp4

# %%
vlc EXPERIMENT/YouTube_dup-1_max10-intro.mp4
